# %% [markdown]
# # 1 ::  Import Liberaries

# %%
import requests as R
import json , csv
import pandas as pd
import sqlite3 as S

# %% [markdown]
# # 2 ::Request to url and get response of that request

# %%
url =  "https://gorest.co.in/public-api/users?_format=json&access-token=H4lYmIGLXZkDlpy_w0ZVS5rgcpDXbN7fhRRy"
res= R.get(url)

# %%
res.text
# Out:
# '{"code":200,"meta":{"pagination":{"total":1462,"pages":74,"page":1,"limit":20}},"data":[{"id":2,"name":"Patricia","email":"patricia1234@gmail.com","gender":"Female","status":"Active","created_at":"2021-01-06T03:50:03.569+05:30","updated_at":"2021-01-06T18:32:59.594+05:30"},{"id":4,"name":"kat1","email":"qwe1@mail.ru","gender":"Male","status":"Active","created_at":"2021-01-06T03:50:03.596+05:30","updated_at":"2021-01-06T14:29:53.218+05:30"},{"id":5,"name":"Chidaatma Jain","email":"jain_chidaatma@aufderhar-bergstrom.com","gender":"Female","status":"Inactive","created_at":"2021-01-06T03:50:03.607+05:30","updated_at":"2021-01-06T03:50:03.607+05:30"},{"id":6,"name":"Lakshman Patel","email":"lakshman_patel@hand.info","gender":"Female","status":"Inactive","created_at":"2021-01-06T03:50:03.637+05:30","updated_at":"2021-01-06T03:50:03.637+05:30"},{"id":7,"name":"Aashritha Nair","email":"aashritha_nair@skiles.co","gender":"Male","status":"Inactive","created_at":"2021-01-06T03:50:03.644+05:30","updated_at":"2021-01-06T03:50:03.644+05:30"},{"id":8,"name":"Rohan Tagore","email":"tagore_rohan@hills-brekke.info","gender":"Male","status":"Active","created_at":"2021-01-06T03:50:03.678+05:30","updated_at":"2021-01-06T03:50:03.678+05:30"},{"id":9,"name":"Rita Reddy","email":"reddy_rita@kautzer.org","gender":"Male","status":"Inactive","created_at":"2021-01-06T03:50:03.706+05:30","updated_at":"2021-01-06T03:50:03.706+05:30"},{"id":11,"name":"Lakshminath Deshpande","email":"lakshminath_deshpande@lang-trantow.biz","gender":"Female","status":"Inactive","created_at":"2021-01-06T03:50:03.732+05:30","updated_at":"2021-01-06T03:50:03.732+05:30"},{"id":13,"name":"Devvrat Saini","email":"devvrat_saini@bins.info","gender":"Female","status":"Inactive","created_at":"2021-01-06T03:50:03.785+05:30","updated_at":"2021-01-06T03:50:03.785+05:30"},{"id":14,"name":"Aditya Gill","email":"aditya_gill@leannon.name","gender":"Female","status":"Inactive","created_at":"2021-01-06T03:50:03.798+05:30","updated_at":"2021-01-06T03:50:03.798+05:30"},{"id":17,"name":"Ms. Sitara Pothuvaal","email":"sitara_pothuvaal_ms@kilback.co","gender":"Male","status":"Active","created_at":"2021-01-06T03:50:03.826+05:30","updated_at":"2021-01-06T03:50:03.826+05:30"},{"id":18,"name":"Msgr. Kamalesh Mahajan","email":"msgr_kamalesh_mahajan@robel-ruecker.co","gender":"Male","status":"Active","created_at":"2021-01-06T03:50:03.849+05:30","updated_at":"2021-01-06T03:50:03.849+05:30"},{"id":19,"name":"Jahnu Panicker","email":"jahnu_panicker@treutel.info","gender":"Male","status":"Active","created_at":"2021-01-06T03:50:03.876+05:30","updated_at":"2021-01-06T03:50:03.876+05:30"},{"id":20,"name":"Bharadwaj Rana MD","email":"rana_bharadwaj_md@witting.net","gender":"Female","status":"Inactive","created_at":"2021-01-06T03:50:03.881+05:30","updated_at":"2021-01-06T03:50:03.881+05:30"},{"id":23,"name":"Gautami Joshi","email":"gautami_joshi@schuppe.io","gender":"Female","status":"Inactive","created_at":"2021-01-06T03:50:03.918+05:30","updated_at":"2021-01-06T03:50:03.918+05:30"},{"id":24,"name":"Sen. Lai Joshi","email":"lai_joshi_sen@gerlach-hegmann.net","gender":"Male","status":"Inactive","created_at":"2021-01-06T03:50:03.945+05:30","updated_at":"2021-01-06T03:50:03.945+05:30"},{"id":25,"name":"Kumari Patil","email":"patil_kumari@barrows.net","gender":"Female","status":"Active","created_at":"2021-01-06T03:50:03.950+05:30","updated_at":"2021-01-06T03:50:03.950+05:30"},{"id":26,"name":"Washington Luis Cabral da Silva","email":"wluissilva@live.com","gender":"Male","status":"Active","created_at":"2021-01-06T03:50:03.963+05:30","updated_at":"2021-01-06T08:36:55.184+05:30"},{"id":27,"name":"Vedanshi Tandon","email":"vedanshi_tandon@olson.io","gender":"Male","status":"Active","created_at":"2021-01-06T03:50:03.984+05:30","updated_at":"2021-01-06T03:50:03.984+05:30"},{"id":28,"name":"Omana Kaul","email":"omana_kaul@lebsack.info","gender":"Female","status":"Active","created_at":"2021-01-06T03:50:03.987+05:30","update ...

# %%
type(res.text)
# Out:
# str

# %% [markdown]
# # 3 :: Loads data using json

# %%
res_json = json.loads(res.text)

# %%
res_json
# Out:
# {'code': 200,
#  'meta': {'pagination': {'total': 1462, 'pages': 74, 'page': 1, 'limit': 20}},
#  'data': [{'id': 2,
#    'name': 'Patricia',
#    'email': 'patricia1234@gmail.com',
#    'gender': 'Female',
#    'status': 'Active',
#    'created_at': '2021-01-06T03:50:03.569+05:30',
#    'updated_at': '2021-01-06T18:32:59.594+05:30'},
#   {'id': 4,
#    'name': 'kat1',
#    'email': 'qwe1@mail.ru',
#    'gender': 'Male',
#    'status': 'Active',
#    'created_at': '2021-01-06T03:50:03.596+05:30',
#    'updated_at': '2021-01-06T14:29:53.218+05:30'},
#   {'id': 5,
#    'name': 'Chidaatma Jain',
#    'email': 'jain_chidaatma@aufderhar-bergstrom.com',
#    'gender': 'Female',
#    'status': 'Inactive',
#    'created_at': '2021-01-06T03:50:03.607+05:30',
#    'updated_at': '2021-01-06T03:50:03.607+05:30'},
#   {'id': 6,
#    'name': 'Lakshman Patel',
#    'email': 'lakshman_patel@hand.info',
#    'gender': 'Female',
#    'status': 'Inactive',
#    'created_at': '2021-01-06T03:50:03.637+05:30',
#    'updated_at': '2021-01-06T03:50:03.637+05:30'},
#   {'id': 7,
#    'name': 'Aashritha Nair',
#    'email': 'aashritha_nair@skiles.co',
#    'gender': 'Male',
#    'status': 'Inactive',
#    'created_at': '2021-01-06T03:50:03.644+05:30',
#    'updated_at': '2021-01-06T03:50:03.644+05:30'},
#   {'id': 8,
#    'name': 'Rohan Tagore',
#    'email': 'tagore_rohan@hills-brekke.info',
#    'gender': 'Male',
#    'status': 'Active',
#    'created_at': '2021-01-06T03:50:03.678+05:30',
#    'updated_at': '2021-01-06T03:50:03.678+05:30'},
#   {'id': 9,
#    'name': 'Rita Reddy',
#    'email': 'reddy_rita@kautzer.org',
#    'gender': 'Male',
#    'status': 'Inactive',
#    'created_at': '2021-01-06T03:50:03.706+05:30',
#    'updated_at': '2021-01-06T03:50:03.706+05:30'},
#   {'id': 11,
#    'name': 'Lakshminath Deshpande',
#    'email': 'lakshminath_deshpande@lang-trantow.biz',
#    'gender': 'Female',
#    'status': 'Inactive',
#    'created_at': '2021-01-06T03:50:03.732+05:30',
#    'updated_at': '2021-01-06T03:50:03.732+05:30'},
#   {'id': 13,
#    'name': 'Devvrat Saini',
#    'email': 'devvrat_saini@bins.info',
#    'gender': 'Female',
#    'status': 'Inactive',
#    'created_at': '2021-01-06T03:50:03.785+05:30',
#    'updated_at': '2021-01-06T03:50:03.785+05:30'},
#   {'id': 14,
#    'name': 'Aditya Gill',
#    'email': 'aditya_gill@leannon.name',
#    'gender': 'Female',
#    'status': 'Inactive',
#    'created_at': '2021-01-06T03:50:03.798+05:30',
#    'updated_at': '2021-01-06T03:50:03.798+05:30'},
#   {'id': 17,
#    'name': 'Ms. Sitara Pothuvaal',
#    'email': 'sitara_pothuvaal_ms@kilback.co',
#    'gender': 'Male',
#    'status': 'Active',
#    'created_at': '2021-01-06T03:50:03.826+05:30',
#    'updated_at': '2021-01-06T03:50:03.826+05:30'},
#   {'id': 18,
#    'name': 'Msgr. Kamalesh Mahajan',
#    'email': 'msgr_kamalesh_mahajan@robel-ruecker.co',
#    'gender': 'Male',
#    'status': 'Active',
#    'created_at': '2021-01-06T03:50:03.849+05:30',
#    'updated_at': '2021-01-06T03:50:03.849+05:30'},
#   {'id': 19,
#    'name': 'Jahnu Panicker',
#    'email': 'jahnu_panicker@treutel.info',
#    'gender': 'Male',
#    'status': 'Active',
#    'created_at': '2021-01-06T03:50:03.876+05:30',
#    'updated_at': '2021-01-06T03:50:03.876+05:30'},
#   {'id': 20,
#    'name': 'Bharadwaj Rana MD',
#    'email': 'rana_bharadwaj_md@witting.net',
#    'gender': 'Female',
#    'status': 'Inactive',
#    'created_at': '2021-01-06T03:50:03.881+05:30',
#    'updated_at': '2021-01-06T03:50:03.881+05:30'},
#   {'id': 23,
#    'name': 'Gautami Joshi',
#    'email': 'gautami_joshi@schuppe.io',
#    'gender': 'Female',
#    'status': 'Inactive',
#    'created_at': '2021-01-06T03:50:03.918+05:30',
#    'updated_at': '2021-01-06T03:50:03.918+05:30'},
#   {'id': 24,
#    'name': 'Sen. Lai Joshi',
#    'email': 'lai_joshi_sen@gerlach-hegmann.net',
#    'gender': 'Male',
#    'status': 'Inactive',
#    'created_at': '2021-01-06T03:50:03.945+05:30',
#    'updated_at': '2021-01-06T03:50:03.945+05:30'},
#   {'id': 25,
#    'name': 'Kumari Patil',
#    'email': 'patil_kumari@barrows.net',
#    'gender': 'Female',
#    'status': 'Active',
#    'created_at': '2021-01-06T03:50:03.950+05:30',
#    'updated_at': '2021-01-06T03:50:03.950+05:30'},
#   {'id': 26,
#    'name': 'Washington Luis Cabral da Silva',
#    'email': 'wluissilva@live.com',
#    'gender': 'Male',
#    'status': 'Active',
#    'created_at': '2021-01-06T03:50:03.963+05:30',
#    'updated_at': '2021-01-06T08:36:55.184+05:30'},
#   {'id': 27,
#    'name': 'Vedanshi Tandon',
#    'email': 'vedanshi_tandon@olson.io',
#    'gender': 'Male',
#    'status': 'Active',
#    'created_at': '2021-01-06T03:50:03.984+05:30',
#    'updated_at': '2021-01-06T03:50:03.984+05:30'},
#   {'id': 28,
#    'name': 'Omana Kaul',
#    'email': 'omana_kaul@lebsack.info',
#    'gender': 'Female',
#    'status': 'Active',
#    'created_at': '2021-01-06T03:50:03.987+05:30',
#    'updated_at': '2021-01-06T03:50:03.987+05:30'}]}

# %%
type(res_json)
# Out:
# dict

# %% [markdown]
# # 4 :: determine data we need to get and find meta data of it

# %%
users = res_json["data"]
users
# Out:
# [{'id': 2,
#   'name': 'Patricia',
#   'email': 'patricia1234@gmail.com',
#   'gender': 'Female',
#   'status': 'Active',
#   'created_at': '2021-01-06T03:50:03.569+05:30',
#   'updated_at': '2021-01-06T18:32:59.594+05:30'},
#  {'id': 4,
#   'name': 'kat1',
#   'email': 'qwe1@mail.ru',
#   'gender': 'Male',
#   'status': 'Active',
#   'created_at': '2021-01-06T03:50:03.596+05:30',
#   'updated_at': '2021-01-06T14:29:53.218+05:30'},
#  {'id': 5,
#   'name': 'Chidaatma Jain',
#   'email': 'jain_chidaatma@aufderhar-bergstrom.com',
#   'gender': 'Female',
#   'status': 'Inactive',
#   'created_at': '2021-01-06T03:50:03.607+05:30',
#   'updated_at': '2021-01-06T03:50:03.607+05:30'},
#  {'id': 6,
#   'name': 'Lakshman Patel',
#   'email': 'lakshman_patel@hand.info',
#   'gender': 'Female',
#   'status': 'Inactive',
#   'created_at': '2021-01-06T03:50:03.637+05:30',
#   'updated_at': '2021-01-06T03:50:03.637+05:30'},
#  {'id': 7,
#   'name': 'Aashritha Nair',
#   'email': 'aashritha_nair@skiles.co',
#   'gender': 'Male',
#   'status': 'Inactive',
#   'created_at': '2021-01-06T03:50:03.644+05:30',
#   'updated_at': '2021-01-06T03:50:03.644+05:30'},
#  {'id': 8,
#   'name': 'Rohan Tagore',
#   'email': 'tagore_rohan@hills-brekke.info',
#   'gender': 'Male',
#   'status': 'Active',
#   'created_at': '2021-01-06T03:50:03.678+05:30',
#   'updated_at': '2021-01-06T03:50:03.678+05:30'},
#  {'id': 9,
#   'name': 'Rita Reddy',
#   'email': 'reddy_rita@kautzer.org',
#   'gender': 'Male',
#   'status': 'Inactive',
#   'created_at': '2021-01-06T03:50:03.706+05:30',
#   'updated_at': '2021-01-06T03:50:03.706+05:30'},
#  {'id': 11,
#   'name': 'Lakshminath Deshpande',
#   'email': 'lakshminath_deshpande@lang-trantow.biz',
#   'gender': 'Female',
#   'status': 'Inactive',
#   'created_at': '2021-01-06T03:50:03.732+05:30',
#   'updated_at': '2021-01-06T03:50:03.732+05:30'},
#  {'id': 13,
#   'name': 'Devvrat Saini',
#   'email': 'devvrat_saini@bins.info',
#   'gender': 'Female',
#   'status': 'Inactive',
#   'created_at': '2021-01-06T03:50:03.785+05:30',
#   'updated_at': '2021-01-06T03:50:03.785+05:30'},
#  {'id': 14,
#   'name': 'Aditya Gill',
#   'email': 'aditya_gill@leannon.name',
#   'gender': 'Female',
#   'status': 'Inactive',
#   'created_at': '2021-01-06T03:50:03.798+05:30',
#   'updated_at': '2021-01-06T03:50:03.798+05:30'},
#  {'id': 17,
#   'name': 'Ms. Sitara Pothuvaal',
#   'email': 'sitara_pothuvaal_ms@kilback.co',
#   'gender': 'Male',
#   'status': 'Active',
#   'created_at': '2021-01-06T03:50:03.826+05:30',
#   'updated_at': '2021-01-06T03:50:03.826+05:30'},
#  {'id': 18,
#   'name': 'Msgr. Kamalesh Mahajan',
#   'email': 'msgr_kamalesh_mahajan@robel-ruecker.co',
#   'gender': 'Male',
#   'status': 'Active',
#   'created_at': '2021-01-06T03:50:03.849+05:30',
#   'updated_at': '2021-01-06T03:50:03.849+05:30'},
#  {'id': 19,
#   'name': 'Jahnu Panicker',
#   'email': 'jahnu_panicker@treutel.info',
#   'gender': 'Male',
#   'status': 'Active',
#   'created_at': '2021-01-06T03:50:03.876+05:30',
#   'updated_at': '2021-01-06T03:50:03.876+05:30'},
#  {'id': 20,
#   'name': 'Bharadwaj Rana MD',
#   'email': 'rana_bharadwaj_md@witting.net',
#   'gender': 'Female',
#   'status': 'Inactive',
#   'created_at': '2021-01-06T03:50:03.881+05:30',
#   'updated_at': '2021-01-06T03:50:03.881+05:30'},
#  {'id': 23,
#   'name': 'Gautami Joshi',
#   'email': 'gautami_joshi@schuppe.io',
#   'gender': 'Female',
#   'status': 'Inactive',
#   'created_at': '2021-01-06T03:50:03.918+05:30',
#   'updated_at': '2021-01-06T03:50:03.918+05:30'},
#  {'id': 24,
#   'name': 'Sen. Lai Joshi',
#   'email': 'lai_joshi_sen@gerlach-hegmann.net',
#   'gender': 'Male',
#   'status': 'Inactive',
#   'created_at': '2021-01-06T03:50:03.945+05:30',
#   'updated_at': '2021-01-06T03:50:03.945+05:30'},
#  {'id': 25,
#   'name': 'Kumari Patil',
#   'email': 'patil_kumari@barrows.net',
#   'gender': 'Female',
#   'status': 'Active',
#   'created_at': '2021-01-06T03:50:03.950+05:30',
#   'updated_at': '2021-01-06T03:50:03.950+05:30'},
#  {'id': 26,
#   'name': 'Washington Luis Cabral da Silva',
#   'email': 'wluissilva@live.com',
#   'gender': 'Male',
#   'status': 'Active',
#   'created_at': '2021-01-06T03:50:03.963+05:30',
#   'updated_at': '2021-01-06T08:36:55.184+05:30'},
#  {'id': 27,
#   'name': 'Vedanshi Tandon',
#   'email': 'vedanshi_tandon@olson.io',
#   'gender': 'Male',
#   'status': 'Active',
#   'created_at': '2021-01-06T03:50:03.984+05:30',
#   'updated_at': '2021-01-06T03:50:03.984+05:30'},
#  {'id': 28,
#   'name': 'Omana Kaul',
#   'email': 'omana_kaul@lebsack.info',
#   'gender': 'Female',
#   'status': 'Active',
#   'created_at': '2021-01-06T03:50:03.987+05:30',
#   'updated_at': '2021-01-06T03:50:03.987+05:30'}]

# %%
for user in users :
    U_Id     =user["id"]
    U_Name   =user["name"]
    U_e_mail =user["email"]
    U_Gender =user["gender"]
    U_Status = user["status"]
    U_created_at =user["created_at"]
    U_updated_at =user["updated_at"]
    print(f"U_Id :: {U_Id}\nU_Name :: {U_Name}\nU_E_mail :: {U_e_mail}\nU_Gender :: {U_Gender}\nU_Status :: {U_Status}\nU_Created :: {U_created_at}\nU_Updated :: {U_updated_at}\n-------------------")
# Out:
# U_Id :: 2
# U_Name :: Patricia
# U_E_mail :: patricia1234@gmail.com
# U_Gender :: Female
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.569+05:30
# U_Updated :: 2021-01-06T18:32:59.594+05:30
# -------------------
# U_Id :: 4
# U_Name :: kat1
# U_E_mail :: qwe1@mail.ru
# U_Gender :: Male
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.596+05:30
# U_Updated :: 2021-01-06T14:29:53.218+05:30
# -------------------
# U_Id :: 5
# U_Name :: Chidaatma Jain
# U_E_mail :: jain_chidaatma@aufderhar-bergstrom.com
# U_Gender :: Female
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.607+05:30
# U_Updated :: 2021-01-06T03:50:03.607+05:30
# -------------------
# U_Id :: 6
# U_Name :: Lakshman Patel
# U_E_mail :: lakshman_patel@hand.info
# U_Gender :: Female
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.637+05:30
# U_Updated :: 2021-01-06T03:50:03.637+05:30
# -------------------
# U_Id :: 7
# U_Name :: Aashritha Nair
# U_E_mail :: aashritha_nair@skiles.co
# U_Gender :: Male
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.644+05:30
# U_Updated :: 2021-01-06T03:50:03.644+05:30
# -------------------
# U_Id :: 8
# U_Name :: Rohan Tagore
# U_E_mail :: tagore_rohan@hills-brekke.info
# U_Gender :: Male
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.678+05:30
# U_Updated :: 2021-01-06T03:50:03.678+05:30
# -------------------
# U_Id :: 9
# U_Name :: Rita Reddy
# U_E_mail :: reddy_rita@kautzer.org
# U_Gender :: Male
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.706+05:30
# U_Updated :: 2021-01-06T03:50:03.706+05:30
# -------------------
# U_Id :: 11
# U_Name :: Lakshminath Deshpande
# U_E_mail :: lakshminath_deshpande@lang-trantow.biz
# U_Gender :: Female
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.732+05:30
# U_Updated :: 2021-01-06T03:50:03.732+05:30
# -------------------
# U_Id :: 13
# U_Name :: Devvrat Saini
# U_E_mail :: devvrat_saini@bins.info
# U_Gender :: Female
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.785+05:30
# U_Updated :: 2021-01-06T03:50:03.785+05:30
# -------------------
# U_Id :: 14
# U_Name :: Aditya Gill
# U_E_mail :: aditya_gill@leannon.name
# U_Gender :: Female
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.798+05:30
# U_Updated :: 2021-01-06T03:50:03.798+05:30
# -------------------
# U_Id :: 17
# U_Name :: Ms. Sitara Pothuvaal
# U_E_mail :: sitara_pothuvaal_ms@kilback.co
# U_Gender :: Male
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.826+05:30
# U_Updated :: 2021-01-06T03:50:03.826+05:30
# -------------------
# U_Id :: 18
# U_Name :: Msgr. Kamalesh Mahajan
# U_E_mail :: msgr_kamalesh_mahajan@robel-ruecker.co
# U_Gender :: Male
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.849+05:30
# U_Updated :: 2021-01-06T03:50:03.849+05:30
# -------------------
# U_Id :: 19
# U_Name :: Jahnu Panicker
# U_E_mail :: jahnu_panicker@treutel.info
# U_Gender :: Male
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.876+05:30
# U_Updated :: 2021-01-06T03:50:03.876+05:30
# -------------------
# U_Id :: 20
# U_Name :: Bharadwaj Rana MD
# U_E_mail :: rana_bharadwaj_md@witting.net
# U_Gender :: Female
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.881+05:30
# U_Updated :: 2021-01-06T03:50:03.881+05:30
# -------------------
# U_Id :: 23
# U_Name :: Gautami Joshi
# U_E_mail :: gautami_joshi@schuppe.io
# U_Gender :: Female
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.918+05:30
# U_Updated :: 2021-01-06T03:50:03.918+05:30
# -------------------
# U_Id :: 24
# U_Name :: Sen. Lai Joshi
# U_E_mail :: lai_joshi_sen@gerlach-hegmann.net
# U_Gender :: Male
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.945+05:30
# U_Updated :: 2021-01-06T03:50:03.945+05:30
# -------------------
# U_Id :: 25
# U_Name :: Kumari Patil
# U_E_mail :: patil_kumari@barrows.net
# U_Gender :: Female
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.950+05:30
# U_Updated :: 2021-01-06T03:50:03.950+05:30
# -------------------
# U_Id :: 26
# U_Name :: Washington Luis Cabral da Silva
# U_E_mail :: wluissilva@live.com
# U_Gender :: Male
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.963+05:30
# U_Updated :: 2021-01-06T08:36:55.184+05:30
# -------------------
# U_Id :: 27
# U_Name :: Vedanshi Tandon
# U_E_mail :: vedanshi_tandon@olson.io
# U_Gender :: Male
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.984+05:30
# U_Updated :: 2021-01-06T03:50:03.984+05:30
# -------------------
# U_Id :: 28
# U_Name :: Omana Kaul
# U_E_mail :: omana_kaul@lebsack.info
# U_Gender :: Female
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.987+05:30
# U_Updated :: 2021-01-06T03:50:03.987+05:30
# -------------------

# %% [markdown]
# # 5 :: Create function to create csv_file to save data in it

# %%
def get_users_data(url):
    with open("users_data_set.csv" , "w") as f :
        writer = csv.DictWriter( f , fieldnames= [ "ID" , "Name" , "E_mail" , "Gender" , "Status" , "creation" , "Updation"])
        writer.writeheader()
        res = R.get(url)
        res_json = json.loads(res.text)
        users = res_json["data"]
        for user in users :
            U_Id     =user["id"]
            U_Name   =user["name"]
            U_e_mail =user["email"]
            U_Gender =user["gender"]
            U_Status = user["status"]
            U_created_at =user["created_at"]
            U_updated_at =user["updated_at"]
            writer.writerow({"ID":U_Id ,"Name" : U_Name ,"E_mail" :U_e_mail ,"Gender" :U_Gender , "Status": U_Status, "creation":U_created_at ,"Updation" :U_updated_at})
            print(f"U_Id :: {U_Id}\nU_Name :: {U_Name}\nU_E_mail :: {U_e_mail}\nU_Gender :: {U_Gender}\nU_Status :: {U_Status}\nU_Created :: {U_created_at}\nU_Updated :: {U_updated_at}\n-------------------")

# %%
get_users_data("https://gorest.co.in/public-api/users?_format=json&access-token=H4lYmIGLXZkDlpy_w0ZVS5rgcpDXbN7fhRRy")
# Out:
# U_Id :: 2
# U_Name :: Patricia
# U_E_mail :: patricia1234@gmail.com
# U_Gender :: Female
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.569+05:30
# U_Updated :: 2021-01-06T18:32:59.594+05:30
# -------------------
# U_Id :: 4
# U_Name :: kat1
# U_E_mail :: qwe1@mail.ru
# U_Gender :: Male
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.596+05:30
# U_Updated :: 2021-01-06T14:29:53.218+05:30
# -------------------
# U_Id :: 5
# U_Name :: Chidaatma Jain
# U_E_mail :: jain_chidaatma@aufderhar-bergstrom.com
# U_Gender :: Female
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.607+05:30
# U_Updated :: 2021-01-06T03:50:03.607+05:30
# -------------------
# U_Id :: 6
# U_Name :: Lakshman Patel
# U_E_mail :: lakshman_patel@hand.info
# U_Gender :: Female
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.637+05:30
# U_Updated :: 2021-01-06T03:50:03.637+05:30
# -------------------
# U_Id :: 7
# U_Name :: Aashritha Nair
# U_E_mail :: aashritha_nair@skiles.co
# U_Gender :: Male
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.644+05:30
# U_Updated :: 2021-01-06T03:50:03.644+05:30
# -------------------
# U_Id :: 8
# U_Name :: Rohan Tagore
# U_E_mail :: tagore_rohan@hills-brekke.info
# U_Gender :: Male
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.678+05:30
# U_Updated :: 2021-01-06T03:50:03.678+05:30
# -------------------
# U_Id :: 9
# U_Name :: Rita Reddy
# U_E_mail :: reddy_rita@kautzer.org
# U_Gender :: Male
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.706+05:30
# U_Updated :: 2021-01-06T03:50:03.706+05:30
# -------------------
# U_Id :: 11
# U_Name :: Lakshminath Deshpande
# U_E_mail :: lakshminath_deshpande@lang-trantow.biz
# U_Gender :: Female
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.732+05:30
# U_Updated :: 2021-01-06T03:50:03.732+05:30
# -------------------
# U_Id :: 13
# U_Name :: Devvrat Saini
# U_E_mail :: devvrat_saini@bins.info
# U_Gender :: Female
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.785+05:30
# U_Updated :: 2021-01-06T03:50:03.785+05:30
# -------------------
# U_Id :: 14
# U_Name :: Aditya Gill
# U_E_mail :: aditya_gill@leannon.name
# U_Gender :: Female
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.798+05:30
# U_Updated :: 2021-01-06T03:50:03.798+05:30
# -------------------
# U_Id :: 17
# U_Name :: Ms. Sitara Pothuvaal
# U_E_mail :: sitara_pothuvaal_ms@kilback.co
# U_Gender :: Male
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.826+05:30
# U_Updated :: 2021-01-06T03:50:03.826+05:30
# -------------------
# U_Id :: 18
# U_Name :: Msgr. Kamalesh Mahajan
# U_E_mail :: msgr_kamalesh_mahajan@robel-ruecker.co
# U_Gender :: Male
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.849+05:30
# U_Updated :: 2021-01-06T03:50:03.849+05:30
# -------------------
# U_Id :: 19
# U_Name :: Jahnu Panicker
# U_E_mail :: jahnu_panicker@treutel.info
# U_Gender :: Male
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.876+05:30
# U_Updated :: 2021-01-06T03:50:03.876+05:30
# -------------------
# U_Id :: 20
# U_Name :: Bharadwaj Rana MD
# U_E_mail :: rana_bharadwaj_md@witting.net
# U_Gender :: Female
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.881+05:30
# U_Updated :: 2021-01-06T03:50:03.881+05:30
# -------------------
# U_Id :: 23
# U_Name :: Gautami Joshi
# U_E_mail :: gautami_joshi@schuppe.io
# U_Gender :: Female
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.918+05:30
# U_Updated :: 2021-01-06T03:50:03.918+05:30
# -------------------
# U_Id :: 24
# U_Name :: Sen. Lai Joshi
# U_E_mail :: lai_joshi_sen@gerlach-hegmann.net
# U_Gender :: Male
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.945+05:30
# U_Updated :: 2021-01-06T03:50:03.945+05:30
# -------------------
# U_Id :: 25
# U_Name :: Kumari Patil
# U_E_mail :: patil_kumari@barrows.net
# U_Gender :: Female
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.950+05:30
# U_Updated :: 2021-01-06T03:50:03.950+05:30
# -------------------
# U_Id :: 26
# U_Name :: Washington Luis Cabral da Silva
# U_E_mail :: wluissilva@live.com
# U_Gender :: Male
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.963+05:30
# U_Updated :: 2021-01-06T08:36:55.184+05:30
# -------------------
# U_Id :: 27
# U_Name :: Vedanshi Tandon
# U_E_mail :: vedanshi_tandon@olson.io
# U_Gender :: Male
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.984+05:30
# U_Updated :: 2021-01-06T03:50:03.984+05:30
# -------------------
# U_Id :: 28
# U_Name :: Omana Kaul
# U_E_mail :: omana_kaul@lebsack.info
# U_Gender :: Female
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.987+05:30
# U_Updated :: 2021-01-06T03:50:03.987+05:30
# -------------------

# %% [markdown]
# # 6 :: Present data using Pandas

# %%
data = pd.read_csv("users_data_set.csv")

# %%
data
# Out:
#     ID                             Name  \
# 0    2                         Patricia
# 1    4                             kat1
# 2    5                   Chidaatma Jain
# 3    6                   Lakshman Patel
# 4    7                   Aashritha Nair
# 5    8                     Rohan Tagore
# 6    9                       Rita Reddy
# 7   11            Lakshminath Deshpande
# 8   13                    Devvrat Saini
# 9   14                      Aditya Gill
# 10  17             Ms. Sitara Pothuvaal
# 11  18           Msgr. Kamalesh Mahajan
# 12  19                   Jahnu Panicker
# 13  20                Bharadwaj Rana MD
# 14  23                    Gautami Joshi
# 15  24                   Sen. Lai Joshi
# 16  25                     Kumari Patil
# 17  26  Washington Luis Cabral da Silva
# 18  27                  Vedanshi Tandon
# 19  28                       Omana Kaul
#
#                                     E_mail  Gender    Status  \
# 0                   patricia1234@gmail.com  Female    Active
# 1                             qwe1@mail.ru    Male    Active
# 2   jain_chidaatma@aufderhar-bergstrom.com  Female  Inactive
# 3                 lakshman_patel@hand.info  Female  Inactive
# 4                 aashritha_nair@skiles.co    Male  Inactive
# 5           tagore_rohan@hills-brekke.info    Male    Active
# 6                   reddy_rita@kautzer.org    Male  Inactive
# 7   lakshminath_deshpande@lang-trantow.biz  Female  Inactive
# 8                  devvrat_saini@bins.info  Female  Inactive
# 9                 aditya_gill@leannon.name  Female  Inactive
# 10          sitara_pothuvaal_ms@kilback.co    Male    Active
# 11  msgr_kamalesh_mahajan@robel-ruecker.co    Male    Active
# 12             jahnu_panicker@treutel.info    Male    Active
# 13           rana_bharadwaj_md@witting.net  Female  Inactive
# 14                gautami_joshi@schuppe.io  Female  Inactive
# 15       lai_joshi_sen@gerlach-hegmann.net    Male  Inactive
# 16                patil_kumari@barrows.net  Female    Active
# 17                     wluissilva@live.com    Male    Active
# 18                vedanshi_tandon@olson.io    Male    Active
# 19                 omana_kaul@lebsack.info  Female    Active
#
#                          creation                       Updation
# 0   2021-01-06T03:50:03.569+05:30  2021-01-06T18:32:59.594+05:30
# 1   2021-01-06T03:50:03.596+05:30  2021-01-06T14:29:53.218+05:30
# 2   2021-01-06T03:50:03.607+05:30  2021-01-06T03:50:03.607+05:30
# 3   2021-01-06T03:50:03.637+05:30  2021-01-06T03:50:03.637+05:30
# 4   2021-01-06T03:50:03.644+05:30  2021-01-06T03:50:03.644+05:30
# 5   2021-01-06T03:50:03.678+05:30  2021-01-06T03:50:03.678+05:30
# 6   2021-01-06T03:50:03.706+05:30  2021-01-06T03:50:03.706+05:30
# 7   2021-01-06T03:50:03.732+05:30  2021-01-06T03:50:03.732+05:30
# 8   2021-01-06T03:50:03.785+05:30  2021-01-06T03:50:03.785+05:30
# 9   2021-01-06T03:50:03.798+05:30  2021-01-06T03:50:03.798+05:30
# 10  2021-01-06T03:50:03.826+05:30  2021-01-06T03:50:03.826+05:30
# 11  2021-01-06T03:50:03.849+05:30  2021-01-06T03:50:03.849+05:30
# 12  2021-01-06T03:50:03.876+05:30  2021-01-06T03:50:03.876+05:30
# 13  2021-01-06T03:50:03.881+05:30  2021-01-06T03:50:03.881+05:30
# 14  2021-01-06T03:50:03.918+05:30  2021-01-06T03:50:03.918+05:30
# 15  2021-01-06T03:50:03.945+05:30  2021-01-06T03:50:03.945+05:30
# 16  2021-01-06T03:50:03.950+05:30  2021-01-06T03:50:03.950+05:30
# 17  2021-01-06T03:50:03.963+05:30  2021-01-06T08:36:55.184+05:30
# 18  2021-01-06T03:50:03.984+05:30  2021-01-06T03:50:03.984+05:30
# 19  2021-01-06T03:50:03.987+05:30  2021-01-06T03:50:03.987+05:30

# %% [markdown]
# # 7 :: describe the data values (count , mean , std , max , min  , Q1 , Q2 , Q3)

# %%
data.describe()
# Out:
#               ID
# count  20.000000
# mean   15.300000
# std     8.498297
# min     2.000000
# 25%     7.750000
# 50%    15.500000
# 75%    23.250000
# max    28.000000

# %% [markdown]
# # 8 :: Visaulize data set

# %%
data.plot()

# %% [markdown]
# # save data in database

# %%
for user in users :
    U_Id     =user["id"]
    U_Name   =user["name"]
    U_e_mail =user["email"]
    U_Gender =user["gender"]
    U_Status = user["status"]
    U_created_at =user["created_at"]
    U_updated_at =user["updated_at"]
    con = S.connect("data_set(2).db")
    sql = "insert into Users (Id , Name , Mail , Gender , Status , Creation , Updation) values (?,?,?,?,?,?,?)"
    data = [U_Id ,U_Name , U_e_mail , U_Gender , U_Status ,U_created_at , U_updated_at  ]
    E = con.execute(sql , data)
    con.commit()
    print(f"U_Id :: {U_Id}\nU_Name :: {U_Name}\nU_E_mail :: {U_e_mail}\nU_Gender :: {U_Gender}\nU_Status :: {U_Status}\nU_Created :: {U_created_at}\nU_Updated :: {U_updated_at}\n-------------------")
# Out:
# U_Id :: 2
# U_Name :: Patricia
# U_E_mail :: patricia1234@gmail.com
# U_Gender :: Female
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.569+05:30
# U_Updated :: 2021-01-06T18:32:59.594+05:30
# -------------------
# U_Id :: 4
# U_Name :: kat1
# U_E_mail :: qwe1@mail.ru
# U_Gender :: Male
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.596+05:30
# U_Updated :: 2021-01-06T14:29:53.218+05:30
# -------------------
# U_Id :: 5
# U_Name :: Chidaatma Jain
# U_E_mail :: jain_chidaatma@aufderhar-bergstrom.com
# U_Gender :: Female
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.607+05:30
# U_Updated :: 2021-01-06T03:50:03.607+05:30
# -------------------
# U_Id :: 6
# U_Name :: Lakshman Patel
# U_E_mail :: lakshman_patel@hand.info
# U_Gender :: Female
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.637+05:30
# U_Updated :: 2021-01-06T03:50:03.637+05:30
# -------------------
# U_Id :: 7
# U_Name :: Aashritha Nair
# U_E_mail :: aashritha_nair@skiles.co
# U_Gender :: Male
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.644+05:30
# U_Updated :: 2021-01-06T03:50:03.644+05:30
# -------------------
# U_Id :: 8
# U_Name :: Rohan Tagore
# U_E_mail :: tagore_rohan@hills-brekke.info
# U_Gender :: Male
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.678+05:30
# U_Updated :: 2021-01-06T03:50:03.678+05:30
# -------------------
# U_Id :: 9
# U_Name :: Rita Reddy
# U_E_mail :: reddy_rita@kautzer.org
# U_Gender :: Male
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.706+05:30
# U_Updated :: 2021-01-06T03:50:03.706+05:30
# -------------------
# U_Id :: 11
# U_Name :: Lakshminath Deshpande
# U_E_mail :: lakshminath_deshpande@lang-trantow.biz
# U_Gender :: Female
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.732+05:30
# U_Updated :: 2021-01-06T03:50:03.732+05:30
# -------------------
# U_Id :: 13
# U_Name :: Devvrat Saini
# U_E_mail :: devvrat_saini@bins.info
# U_Gender :: Female
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.785+05:30
# U_Updated :: 2021-01-06T03:50:03.785+05:30
# -------------------
# U_Id :: 14
# U_Name :: Aditya Gill
# U_E_mail :: aditya_gill@leannon.name
# U_Gender :: Female
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.798+05:30
# U_Updated :: 2021-01-06T03:50:03.798+05:30
# -------------------
# U_Id :: 17
# U_Name :: Ms. Sitara Pothuvaal
# U_E_mail :: sitara_pothuvaal_ms@kilback.co
# U_Gender :: Male
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.826+05:30
# U_Updated :: 2021-01-06T03:50:03.826+05:30
# -------------------
# U_Id :: 18
# U_Name :: Msgr. Kamalesh Mahajan
# U_E_mail :: msgr_kamalesh_mahajan@robel-ruecker.co
# U_Gender :: Male
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.849+05:30
# U_Updated :: 2021-01-06T03:50:03.849+05:30
# -------------------
# U_Id :: 19
# U_Name :: Jahnu Panicker
# U_E_mail :: jahnu_panicker@treutel.info
# U_Gender :: Male
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.876+05:30
# U_Updated :: 2021-01-06T03:50:03.876+05:30
# -------------------
# U_Id :: 20
# U_Name :: Bharadwaj Rana MD
# U_E_mail :: rana_bharadwaj_md@witting.net
# U_Gender :: Female
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.881+05:30
# U_Updated :: 2021-01-06T03:50:03.881+05:30
# -------------------
# U_Id :: 23
# U_Name :: Gautami Joshi
# U_E_mail :: gautami_joshi@schuppe.io
# U_Gender :: Female
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.918+05:30
# U_Updated :: 2021-01-06T03:50:03.918+05:30
# -------------------
# U_Id :: 24
# U_Name :: Sen. Lai Joshi
# U_E_mail :: lai_joshi_sen@gerlach-hegmann.net
# U_Gender :: Male
# U_Status :: Inactive
# U_Created :: 2021-01-06T03:50:03.945+05:30
# U_Updated :: 2021-01-06T03:50:03.945+05:30
# -------------------
# U_Id :: 25
# U_Name :: Kumari Patil
# U_E_mail :: patil_kumari@barrows.net
# U_Gender :: Female
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.950+05:30
# U_Updated :: 2021-01-06T03:50:03.950+05:30
# -------------------
# U_Id :: 26
# U_Name :: Washington Luis Cabral da Silva
# U_E_mail :: wluissilva@live.com
# U_Gender :: Male
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.963+05:30
# U_Updated :: 2021-01-06T08:36:55.184+05:30
# -------------------
# U_Id :: 27
# U_Name :: Vedanshi Tandon
# U_E_mail :: vedanshi_tandon@olson.io
# U_Gender :: Male
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.984+05:30
# U_Updated :: 2021-01-06T03:50:03.984+05:30
# -------------------
# U_Id :: 28
# U_Name :: Omana Kaul
# U_E_mail :: omana_kaul@lebsack.info
# U_Gender :: Female
# U_Status :: Active
# U_Created :: 2021-01-06T03:50:03.987+05:30
# U_Updated :: 2021-01-06T03:50:03.987+05:30
# -------------------
