# %%
import random as rd
r = rd.random()
r_int = rd.randint( 1 ,10 )
r_rang1 = rd.randrange( 6 )
r_rang2 = rd.randrange( 0 , 50 )
r_rang_ste1 = rd.randrange( 0 , 10 , 2 )
r_rang_ste2 = rd.randrange( 0 , 10 , 1 )
choi_value1 = rd.choice([ 10 , 20 , 30 ,40 ,50 ])
choi_value2 = rd.choice([ "Ahmed" , "Eslam" , "Ehab" , "Baher" , "Bellal"])
chois_value1 = rd.choices([100,200,300,400,500])
chois_value2 = rd.choices([ "Nouran" , "Ghada" , "Omnia" ,"Salma" , "Shimaa"])
suff_lis = rd.shuffle([1,2,3,4,5] )
samp_v = rd.sample(range(10 , 50) ,5)
unif_v = rd.uniform(10 , 50)
stat = rd.getstate()
setst = rd.setstate(stat)

# %%
print(f' the random random value  is  ::{r}')
print("============")
print(f' the random integer value  is :: {r_int}')
print("============")
print(f' the random range value1  is  :: {r_rang1}')
print("============")
print(f' the random range value2  is :: {r_rang2}')
print("============")
print(f"the random range by step even is :: {r_rang_ste1}")
print("============")
print(f"the random_rang by step odd is :: {r_rang_ste2}")
print("============")
print(f'the choice val1 is ::{choi_value1}')
print("============")
print(f"the choice va is :: {choi_value2}")
print("============")
print(f"the choices value1 is ::  {chois_value1}")
print("============")
print(f"the choices value2 is :: {chois_value2}")
print("============")
print(f"the sample is ::{samp_v}")
print("============")
print(f"the suffle is :: {suff_lis}")
print("============")
print(f"the uniform value of range is :: {unif_v}")
print("=======================================")
print(stat)
print("========================================")
print(setst)
# Out:
#  the random random value  is  ::0.775199051868019
# ...
#  the random integer value  is :: 4
# ...
#  the random range value1  is  :: 3
# ...
#  the random range value2  is :: 33
# ...
# the random range by step even is :: 6
# ...
# the random_rang by step odd is :: 7
# ...
# the choice val1 is ::40
# ...
# the choice va is :: Ehab
# ...
# the choices value1 is ::  [300]
# ...
# the choices value2 is :: ['Ghada']
# ...
# the sample is ::[13, 25, 12, 16, 29]
# ...
# the suffle is :: None
# ...
# the uniform value of range is :: 15.28594947217352
# ...
