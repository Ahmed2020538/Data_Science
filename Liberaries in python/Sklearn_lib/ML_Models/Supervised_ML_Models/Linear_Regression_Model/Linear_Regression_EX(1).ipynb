# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error , mean_squared_error , median_absolute_error

# %%
Bosted_data = load_boston()

X = Bosted_data.data
y = Bosted_data.target

X_train , X_test , y_train , y_test = train_test_split( X , y , test_size = 0.33 , random_state = 44 ,shuffle = True)

Linear_Regression_Model = LinearRegression(fit_intercept = True , copy_X = True , n_jobs = -1 , normalize = True)
Linear_Regression_Model.fit(X_train , y_train)
Model_coef = Linear_Regression_Model.coef_
Model_intercept = Linear_Regression_Model.intercept_

y_pred = Linear_Regression_Model.predict(X_test)

Accuracy_training = Linear_Regression_Model.score(X_train , y_train)
Accuracy_Testing = Linear_Regression_Model.score(X_test , y_test)

MAE = mean_absolute_error(y_test , y_pred , multioutput="uniform_average")
MSE = mean_squared_error(y_test , y_pred , multioutput="uniform_average")
Md_A_E = median_absolute_error(y_test , y_pred )

# %%
X[:10]
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, 0.0000e+00, 5.3800e-01,
#         6.5750e+00, 6.5200e+01, 4.0900e+00, 1.0000e+00, 2.9600e+02,
#         1.5300e+01, 3.9690e+02, 4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, 0.0000e+00, 4.6900e-01,
#         6.4210e+00, 7.8900e+01, 4.9671e+00, 2.0000e+00, 2.4200e+02,
#         1.7800e+01, 3.9690e+02, 9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, 0.0000e+00, 4.6900e-01,
#         7.1850e+00, 6.1100e+01, 4.9671e+00, 2.0000e+00, 2.4200e+02,
#         1.7800e+01, 3.9283e+02, 4.0300e+00],
#        [3.2370e-02, 0.0000e+00, 2.1800e+00, 0.0000e+00, 4.5800e-01,
#         6.9980e+00, 4.5800e+01, 6.0622e+00, 3.0000e+00, 2.2200e+02,
#         1.8700e+01, 3.9463e+02, 2.9400e+00],
#        [6.9050e-02, 0.0000e+00, 2.1800e+00, 0.0000e+00, 4.5800e-01,
#         7.1470e+00, 5.4200e+01, 6.0622e+00, 3.0000e+00, 2.2200e+02,
#         1.8700e+01, 3.9690e+02, 5.3300e+00],
# ...

# %%
y[:10]
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9])

# %%
X_train[:10]
# Out:
# array([[4.34879e+00, 0.00000e+00, 1.81000e+01, 0.00000e+00, 5.80000e-01,
#         6.16700e+00, 8.40000e+01, 3.03340e+00, 2.40000e+01, 6.66000e+02,
#         2.02000e+01, 3.96900e+02, 1.62900e+01],
#        [5.20580e-01, 0.00000e+00, 6.20000e+00, 1.00000e+00, 5.07000e-01,
#         6.63100e+00, 7.65000e+01, 4.14800e+00, 8.00000e+00, 3.07000e+02,
#         1.74000e+01, 3.88450e+02, 9.54000e+00],
#        [1.28160e-01, 1.25000e+01, 6.07000e+00, 0.00000e+00, 4.09000e-01,
#         5.88500e+00, 3.30000e+01, 6.49800e+00, 4.00000e+00, 3.45000e+02,
#         1.89000e+01, 3.96900e+02, 8.79000e+00],
#        [1.69020e-01, 0.00000e+00, 2.56500e+01, 0.00000e+00, 5.81000e-01,
#         5.98600e+00, 8.84000e+01, 1.99290e+00, 2.00000e+00, 1.88000e+02,
#         1.91000e+01, 3.85020e+02, 1.48100e+01],
#        [7.02259e+00, 0.00000e+00, 1.81000e+01, 0.00000e+00, 7.18000e-01,
#         6.00600e+00, 9.53000e+01, 1.87460e+00, 2.40000e+01, 6.66000e+02,
#         2.02000e+01, 3.19980e+02, 1.57000e+01],
# ...

# %%
y_train[:10]
# Out:
# array([19.9, 25.1, 20.9, 21.4, 14.2, 17.8, 18.4, 22.6, 36.2, 16.5])

# %%
X_test[:10]
# Out:
# array([[3.18270e-01, 0.00000e+00, 9.90000e+00, 0.00000e+00, 5.44000e-01,
#         5.91400e+00, 8.32000e+01, 3.99860e+00, 4.00000e+00, 3.04000e+02,
#         1.84000e+01, 3.90700e+02, 1.83300e+01],
#        [1.10690e-01, 0.00000e+00, 1.38900e+01, 1.00000e+00, 5.50000e-01,
#         5.95100e+00, 9.38000e+01, 2.88930e+00, 5.00000e+00, 2.76000e+02,
#         1.64000e+01, 3.96900e+02, 1.79200e+01],
#        [3.67367e+00, 0.00000e+00, 1.81000e+01, 0.00000e+00, 5.83000e-01,
#         6.31200e+00, 5.19000e+01, 3.99170e+00, 2.40000e+01, 6.66000e+02,
#         2.02000e+01, 3.88620e+02, 1.05800e+01],
#        [5.64400e-02, 4.00000e+01, 6.41000e+00, 1.00000e+00, 4.47000e-01,
#         6.75800e+00, 3.29000e+01, 4.07760e+00, 4.00000e+00, 2.54000e+02,
#         1.76000e+01, 3.96900e+02, 3.53000e+00],
#        [3.76619e+01, 0.00000e+00, 1.81000e+01, 0.00000e+00, 6.79000e-01,
#         6.20200e+00, 7.87000e+01, 1.86290e+00, 2.40000e+01, 6.66000e+02,
#         2.02000e+01, 1.88200e+01, 1.45200e+01],
# ...

# %%
y_test[:10]
# Out:
# array([17.8, 21.5, 21.2, 32.4, 10.9, 31.7, 21.4, 24.3, 29.1, 25. ])

# %%
y_pred[:10]
# Out:
# array([18.08835763, 24.29913209, 21.29334432, 35.15238698, 11.99842784,
#        32.40498032, 19.68065774, 24.85610743, 30.68930394, 21.75521651])

# %%
Model_coef
# Out:
# array([-1.52786535e-01,  5.83438345e-02, -5.25729795e-02,  1.74968794e+00,
#        -1.82628401e+01,  3.19751214e+00, -1.82120263e-03, -1.79227933e+00,
#         3.02644015e-01, -1.26348509e-02, -8.73594266e-01,  1.05892477e-02,
#        -4.68960863e-01])

# %%
Model_intercept
# Out:
# 40.163874564712074

# %%
Accuracy_training
# Out:
# 0.7391405291456344

# %%
Accuracy_Testing
# Out:
# 0.7194574243020464

# %%
MAE
# Out:
# 3.639793518611556

# %%
MSE
# Out:
# 27.59356237965675

# %%
Md_A_E
# Out:
# 2.5619786821948587

# %%
print(f"The X_data ::\n====\n{X[:5]}\n============\nThe y_data :: \n{y[:5]}\n=========\nThe X_Train ::\n\
{X_train[:5]}\n=========\nThe X_test ::\n{X_test[:5]}\n=====\nThe y_Train ::\n{y_train}\n====\n\
The y_test ::\n{y_test[:5]}\n======\nThe y_pred ::\n{y_pred[:5]}\n=====\nThe_Model_Coef ::\n===\n {Model_coef}\n=====\n\
The Model_Intercept :: {Model_intercept}\n=======\nThe Accuracy of Traning_data :: {Accuracy_training}\n====\n\
The Accuracy of Testing_data :: {Accuracy_Testing}\n======\nThe MAE :: {MAE}\n=====\nThe MSE :: {MSE}\n====\n\
The Mid_A_E :: {Md_A_E}")
# Out:
# The X_data ::
# ====
# [[6.3200e-03 1.8000e+01 2.3100e+00 0.0000e+00 5.3800e-01 6.5750e+00
#   6.5200e+01 4.0900e+00 1.0000e+00 2.9600e+02 1.5300e+01 3.9690e+02
#   4.9800e+00]
#  [2.7310e-02 0.0000e+00 7.0700e+00 0.0000e+00 4.6900e-01 6.4210e+00
#   7.8900e+01 4.9671e+00 2.0000e+00 2.4200e+02 1.7800e+01 3.9690e+02
#   9.1400e+00]
#  [2.7290e-02 0.0000e+00 7.0700e+00 0.0000e+00 4.6900e-01 7.1850e+00
#   6.1100e+01 4.9671e+00 2.0000e+00 2.4200e+02 1.7800e+01 3.9283e+02
#   4.0300e+00]
#  [3.2370e-02 0.0000e+00 2.1800e+00 0.0000e+00 4.5800e-01 6.9980e+00
#   4.5800e+01 6.0622e+00 3.0000e+00 2.2200e+02 1.8700e+01 3.9463e+02
#   2.9400e+00]
#  [6.9050e-02 0.0000e+00 2.1800e+00 0.0000e+00 4.5800e-01 7.1470e+00
#   5.4200e+01 6.0622e+00 3.0000e+00 2.2200e+02 1.8700e+01 3.9690e+02
#   5.3300e+00]]
# ...
# The y_data ::
# [24.  21.6 34.7 33.4 36.2]
# ...
# The X_Train ::
# [[4.34879e+00 0.00000e+00 1.81000e+01 0.00000e+00 5.80000e-01 6.16700e+00
# ...
