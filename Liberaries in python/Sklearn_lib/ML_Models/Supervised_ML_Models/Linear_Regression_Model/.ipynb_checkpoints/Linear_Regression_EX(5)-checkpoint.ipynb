# %%
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error , mean_squared_error , median_absolute_error

# %%
data = pd.read_csv("G:\\Data Field\\D..S..Course\\data.sc.Asem\\Data\\Data\\2.1 Linear Regression\\satf.csv")

# %%
data
# Out:
#      high_GPA  math_SAT  verb_SAT  comp_GPA  univ_GPA
# 0        3.45       643       589      3.76      3.52
# 1        2.78       558       512      2.87      2.91
# 2        2.52       583       503      2.54      2.40
# 3        3.67       685       602      3.83      3.47
# 4        3.24       592       538      3.29      3.47
# ..        ...       ...       ...       ...       ...
# 100      3.76       605       590      3.74      3.64
# 101      3.49       692       683      3.27      3.42
# 102      3.07       680       692      3.19      3.25
# 103      2.19       617       503      2.98      2.76
# 104      3.46       516       528      3.28      3.41
#
# [105 rows x 5 columns]

# %%
# Spliting data into input and output

# The Traning Based only Multi Features

X = data.iloc[ : , : -1]
y =data.iloc[ : , -1]

# %%
X
# Out:
#      high_GPA  math_SAT  verb_SAT  comp_GPA
# 0        3.45       643       589      3.76
# 1        2.78       558       512      2.87
# 2        2.52       583       503      2.54
# 3        3.67       685       602      3.83
# 4        3.24       592       538      3.29
# ..        ...       ...       ...       ...
# 100      3.76       605       590      3.74
# 101      3.49       692       683      3.27
# 102      3.07       680       692      3.19
# 103      2.19       617       503      2.98
# 104      3.46       516       528      3.28
#
# [105 rows x 4 columns]

# %%
X.shape
# Out:
# (105, 4)

# %%
y
# Out:
# 0      3.52
# 1      2.91
# 2      2.40
# 3      3.47
# 4      3.47
#        ...
# 100    3.64
# 101    3.42
# 102    3.25
# 103    2.76
# 104    3.41
# Name: univ_GPA, Length: 105, dtype: float64

# %%
# increase numbers of features using Ploynomial feature from module Processing

X = PolynomialFeatures(degree= 2).fit_transform(X)

# %%
# spliting data into Training and testing
X_train  , X_test , y_train , y_test = train_test_split( X , y , test_size = 0.2 , random_state = 20 , shuffle = True)

Linear_Regression_Model = LinearRegression(fit_intercept=True , copy_X=True , n_jobs=-1 , normalize=True)
Linear_Regression_Model.fit(X_train, y_train)
Model_Coef = Linear_Regression_Model.coef_
Model_intercept = Linear_Regression_Model.intercept_
Model_Training_Score = Linear_Regression_Model.score(X_train , y_train)
Model_Testing_Score = Linear_Regression_Model.score(X_test , y_test)
y_pred = Linear_Regression_Model.predict(X_test)

# Chek_Model_Accuracy

MAE = mean_absolute_error(y_test , y_pred , multioutput="uniform_average")
MSE = mean_squared_error(y_test , y_pred , multioutput="uniform_average")
Median_A_E = median_absolute_error(y_test , y_pred)

# %%
print(f"The X_train :: \n=====\n{X_train}\n=====\nThe X_test :: \n====\n{X_test}\n====\nThe y_train :: {y_train}\nThe y_test ::\n==\n {y_test}\
\nThe y_predction ::\n {y_pred}\n======\nThe Model Coef :: {Model_Coef}\n=====\nThe Model_intercept :: {Model_intercept}\n========\n\
The traning_Score :: {Model_Training_Score}\n======\nThe Testing_SCore :: {Model_Testing_Score}\n====\nThe MAE :: \
{MAE}\n=======\nThe MSE :: {MSE}\n=======\nThe Median_A_E :: {Median_A_E}")
# Out:
# The X_train ::
# =====
# [[1.00000e+00 3.19000e+00 6.50000e+02 ... 4.67856e+05 2.12724e+03
#   9.67210e+00]
#  [1.00000e+00 2.84000e+00 5.71000e+02 ... 2.94849e+05 1.17831e+03
#   4.70890e+00]
#  [1.00000e+00 2.71000e+00 5.64000e+02 ... 2.94849e+05 1.17831e+03
#   4.70890e+00]
#  ...
#  [1.00000e+00 3.68000e+00 6.83000e+02 ... 4.12164e+05 2.25984e+03
#   1.23904e+01]
#  [1.00000e+00 2.09000e+00 5.54000e+02 ... 2.30400e+05 1.76640e+03
#  [1.00000e+00 2.59000e+00 6.04000e+02 5.82000e+02 3.21000e+00 6.70810e+00
#   1.56436e+03 1.50738e+03 8.31390e+00 3.64816e+05 3.51528e+05 1.93884e+03
#   3.38724e+05 1.86822e+03 1.03041e+01]
#  [1.00000e+00 2.23000e+00 5.51000e+02 5.54000e+02 2.17000e+00 4.97290e+00
#   1.22873e+03 1.23542e+03 4.83910e+00 3.03601e+05 3.05254e+05 1.19567e+03
#   3.06916e+05 1.20218e+03 4.70890e+00]
#  [1.00000e+00 3.15000e+00 6.68000e+02 6.04000e+02 2.98000e+00 9.92250e+00
#   2.10420e+03 1.90260e+03 9.38700e+00 4.46224e+05 4.03472e+05 1.99064e+03
#   3.64816e+05 1.79992e+03 8.88040e+00]
#  [1.00000e+00 3.21000e+00 6.19000e+02 5.73000e+02 2.84000e+00 1.03041e+01
#   1.98699e+03 1.83933e+03 9.11640e+00 3.83161e+05 3.54687e+05 1.75796e+03
#   3.28329e+05 1.62732e+03 8.06560e+00]
#  [1.00000e+00 3.32000e+00 6.19000e+02 5.58000e+02 3.01000e+00 1.10224e+01
#   2.05508e+03 1.85256e+03 9.99320e+00 3.83161e+05 3.45402e+05 1.86319e+03
#   3.11364e+05 1.67958e+03 9.06010e+00]
#  [1.00000e+00 3.42000e+00 6.67000e+02 5.83000e+02 3.09000e+00 1.16964e+01
#   2.28114e+03 1.99386e+03 1.05678e+01 4.44889e+05 3.88861e+05 2.06103e+03
#   3.39889e+05 1.80147e+03 9.54810e+00]
#  [1.00000e+00 2.71000e+00 5.54000e+02 5.38000e+02 2.49000e+00 7.34410e+00
#   1.50134e+03 1.45798e+03 6.74790e+00 3.06916e+05 2.98052e+05 1.37946e+03
#   2.89444e+05 1.33962e+03 6.20010e+00]
#  [1.00000e+00 3.28000e+00 6.28000e+02 5.80000e+02 3.34000e+00 1.07584e+01
#   2.05984e+03 1.90240e+03 1.09552e+01 3.94384e+05 3.64240e+05 2.09752e+03
#   3.36400e+05 1.93720e+03 1.11556e+01]]
# ====
# The y_train :: 97    3.28
# 51    2.40
# 35    2.35
# 37    3.47
# 67    2.34
#       ...
# 28    3.58
# 95    3.24
# 15    3.40
# 90    3.42
# 99    2.08
# Name: univ_GPA, Length: 84, dtype: float64
# The y_test ::
# ==
#  72     3.31
# 78     3.41
# 31     3.60
# 5      2.37
# 2      2.40
# 46     2.52
# 38     3.00
# 100    3.64
# 93     3.28
# 0      3.52
# 39     2.74
# 60     3.08
# 81     3.12
# 12     3.19
# 98     2.29
# 36     3.17
# 48     3.01
# 23     3.37
# 65     3.01
# 53     2.38
# 92     3.49
# Name: univ_GPA, dtype: float64
# The y_predction ::
#  [3.42970414 3.34247004 3.62396493 2.65874801 2.69806943 2.5451959
#  2.86486662 3.68456747 3.28888527 3.57644075 2.29936825 3.24515674
#  3.09940774 3.23025979 2.26552409 3.2233345  3.10119862 3.21331602
#  3.32282527 2.63591291 3.39281065]
# ======
# The Model Coef :: [ 0.00000000e+00 -9.64403485e-01  8.80183738e-03 -1.16250968e-03
#   3.79588746e+00 -1.03879109e-01  3.87305720e-03 -1.36753680e-03
#   5.46354847e-02 -6.94557509e-06  1.32529127e-05 -6.43688784e-03
#  -7.29084083e-06  2.00398648e-03 -9.19649695e-02]
# =====
# The Model_intercept :: -4.822829675041163
# ========
# The traning_Score :: 0.9301156717736019
# ======
# The Testing_SCore :: 0.8271086569413049
# ====
# The MAE :: 0.1298333484782774
# =======
# The MSE :: 0.03087698251238044
# =======
# The Median_A_E :: 0.09119862307487736

# %%
X.shape
# Out:
# (105, 15)
