# %% [markdown]
# # Random Forest Regressor

# %%
#Import Libraries
from sklearn.ensemble import RandomForestRegressor
#----------------------------------------------------

#Applying Random Forest Regressor Model 

'''
sklearn.ensemble.RandomForestRegressor(n_estimators='warn', criterion=’mse’, max_depth=None,
                                       min_samples_split=2, min_samples_leaf=1,min_weight_fraction_leaf=0.0,
                                       max_features=’auto’, max_leaf_nodes=None,min_impurity_decrease=0.0,
                                       min_impurity_split=None, bootstrap=True,oob_score=False, n_jobs=None,
                                       random_state=None, verbose=0,warm_start=False)
'''

RandomForestRegressorModel = RandomForestRegressor(n_estimators=100,max_depth=2, random_state=33)
RandomForestRegressorModel.fit(X_train, y_train)

#Calculating Details
print('Random Forest Regressor Train Score is : ' , RandomForestRegressorModel.score(X_train, y_train))
print('Random Forest Regressor Test Score is : ' , RandomForestRegressorModel.score(X_test, y_test))
print('Random Forest Regressor No. of features are : ' , RandomForestRegressorModel.n_features_)
print('----------------------------------------------------')

#Calculating Prediction
y_pred = RandomForestRegressorModel.predict(X_test)
print('Predicted Value for Random Forest Regressor is : ' , y_pred[:10])

# %% [markdown]
# * imperting liberaries

# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error , mean_squared_error ,median_absolute_error , r2_score

# %% [markdown]
# * Loading data

# %%
X , y = load_boston( return_X_y=True)
print(f"The X_data = \n{X[:10]}\n=====\nThe y_data :: \n{y[:10]}\n======\nThe X_data_shape :: {X.shape}\
\n=========\nThe y_data_shap :: {y.shape}")
# Out:
# The X_data =
# [[6.3200e-03 1.8000e+01 2.3100e+00 0.0000e+00 5.3800e-01 6.5750e+00
#   6.5200e+01 4.0900e+00 1.0000e+00 2.9600e+02 1.5300e+01 3.9690e+02
#   4.9800e+00]
#  [2.7310e-02 0.0000e+00 7.0700e+00 0.0000e+00 4.6900e-01 6.4210e+00
#   7.8900e+01 4.9671e+00 2.0000e+00 2.4200e+02 1.7800e+01 3.9690e+02
#   9.1400e+00]
#  [2.7290e-02 0.0000e+00 7.0700e+00 0.0000e+00 4.6900e-01 7.1850e+00
#   6.1100e+01 4.9671e+00 2.0000e+00 2.4200e+02 1.7800e+01 3.9283e+02
#   4.0300e+00]
#  [3.2370e-02 0.0000e+00 2.1800e+00 0.0000e+00 4.5800e-01 6.9980e+00
#   4.5800e+01 6.0622e+00 3.0000e+00 2.2200e+02 1.8700e+01 3.9463e+02
#   2.9400e+00]
#  [6.9050e-02 0.0000e+00 2.1800e+00 0.0000e+00 4.5800e-01 7.1470e+00
#   5.4200e+01 6.0622e+00 3.0000e+00 2.2200e+02 1.8700e+01 3.9690e+02
#   5.3300e+00]
#  [2.9850e-02 0.0000e+00 2.1800e+00 0.0000e+00 4.5800e-01 6.4300e+00
#   5.8700e+01 6.0622e+00 3.0000e+00 2.2200e+02 1.8700e+01 3.9412e+02
#   5.2100e+00]
#  [8.8290e-02 1.2500e+01 7.8700e+00 0.0000e+00 5.2400e-01 6.0120e+00
#   6.6600e+01 5.5605e+00 5.0000e+00 3.1100e+02 1.5200e+01 3.9560e+02
#   1.2430e+01]
#  [1.4455e-01 1.2500e+01 7.8700e+00 0.0000e+00 5.2400e-01 6.1720e+00
#   9.6100e+01 5.9505e+00 5.0000e+00 3.1100e+02 1.5200e+01 3.9690e+02
#   1.9150e+01]
#  [2.1124e-01 1.2500e+01 7.8700e+00 0.0000e+00 5.2400e-01 5.6310e+00
#   1.0000e+02 6.0821e+00 5.0000e+00 3.1100e+02 1.5200e+01 3.8663e+02
#   2.9930e+01]
#  [1.7004e-01 1.2500e+01 7.8700e+00 0.0000e+00 5.2400e-01 6.0040e+00
#   8.5900e+01 6.5921e+00 5.0000e+00 3.1100e+02 1.5200e+01 3.8671e+02
#   1.7100e+01]]
# =====
# The y_data ::
# [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9]
# ======
# The X_data_shape :: (506, 13)
# =========
# The y_data_shap :: (506,)

# %% [markdown]
# * Spliting data into Training and Testing data

# %%
X_train , X_test , y_train , y_test = train_test_split( X , y , test_size = 0.33 , random_state = 44 , shuffle = True)

print(f"The X_tarin :: \n{X_train[:5]}\n======\nThe X_test ::\n{X_test}\n=====\nThe y_tarin ::\n{y_train[:5]}\
\n=======\nThe y_test ::\n{y_test[:5]}\n====\nThe X_train_shap :: {X_train.shape}\n====\nThe X_test_shap ::\
{X_test.shape}\n======\nThe y_train_shap :: {y_train.shape}\n======\nThe y_test_shap :: {y_test.shape}")
# Out:
# The X_tarin ::
# [[4.34879e+00 0.00000e+00 1.81000e+01 0.00000e+00 5.80000e-01 6.16700e+00
#   8.40000e+01 3.03340e+00 2.40000e+01 6.66000e+02 2.02000e+01 3.96900e+02
#   1.62900e+01]
#  [5.20580e-01 0.00000e+00 6.20000e+00 1.00000e+00 5.07000e-01 6.63100e+00
#   7.65000e+01 4.14800e+00 8.00000e+00 3.07000e+02 1.74000e+01 3.88450e+02
#   9.54000e+00]
#  [1.28160e-01 1.25000e+01 6.07000e+00 0.00000e+00 4.09000e-01 5.88500e+00
#   3.30000e+01 6.49800e+00 4.00000e+00 3.45000e+02 1.89000e+01 3.96900e+02
#   8.79000e+00]
#  [1.69020e-01 0.00000e+00 2.56500e+01 0.00000e+00 5.81000e-01 5.98600e+00
#   8.84000e+01 1.99290e+00 2.00000e+00 1.88000e+02 1.91000e+01 3.85020e+02
#   1.48100e+01]
#  [7.02259e+00 0.00000e+00 1.81000e+01 0.00000e+00 7.18000e-01 6.00600e+00
#   9.53000e+01 1.87460e+00 2.40000e+01 6.66000e+02 2.02000e+01 3.19980e+02
#   1.57000e+01]]
# ======
# The X_test ::
# [[3.18270e-01 0.00000e+00 9.90000e+00 ... 1.84000e+01 3.90700e+02
#   1.83300e+01]
#  [1.10690e-01 0.00000e+00 1.38900e+01 ... 1.64000e+01 3.96900e+02
#   1.79200e+01]
#  [3.67367e+00 0.00000e+00 1.81000e+01 ... 2.02000e+01 3.88620e+02
#   1.05800e+01]
#  ...
#  [1.46336e+00 0.00000e+00 1.95800e+01 ... 1.47000e+01 3.74430e+02
#   1.73000e+00]
#  [9.32909e+00 0.00000e+00 1.81000e+01 ... 2.02000e+01 3.96900e+02
#   1.81300e+01]
#  [4.52700e-02 0.00000e+00 1.19300e+01 ... 2.10000e+01 3.96900e+02
#   9.08000e+00]]
# =====
# The y_tarin ::
# [19.9 25.1 20.9 21.4 14.2]
# =======
# The y_test ::
# [17.8 21.5 21.2 32.4 10.9]
# ====
# The X_train_shap :: (339, 13)
# ====
# The X_test_shap ::(167, 13)
# ======
# The y_train_shap :: (339,)
# ======
# The y_test_shap :: (167,)

# %% [markdown]
# * Aplly Random_Fores_Regressor

# %%
Random_Forest_reg = RandomForestRegressor(n_estimators=100 , random_state =44 , max_depth =2)
Random_Forest_reg.fit(X_train , y_train)
Model_Train_Score = Random_Forest_reg.score( X_train , y_train)
Model_Test_Score = Random_Forest_reg.score( X_test , y_test)
Model_Fetures = Random_Forest_reg.n_features_
y_pred = Random_Forest_reg.predict(X_test)

# Computing Model Accuracy

MAE = mean_absolute_error( y_test , y_pred , multioutput="uniform_average")
MSE = mean_squared_error(y_test , y_pred, multioutput="uniform_average")
Mid_A_E = median_absolute_error(y_test , y_pred)
R2_Score = r2_score(y_test , y_pred)

print(f"The Model_Train_Score :: {Model_Train_Score}\n======\nThe Model_Test_Score ::\
{Model_Test_Score}\n======\nThe Model_Fetures :: {Model_Fetures}\n======\nThe MAE :: {MAE}\n======\n\
The MSE :: {MSE}\n======\nThe Mid_A_E :: {Mid_A_E}\n=======\nThe R2_Score :: {R2_Score}")
# Out:
# The Model_Train_Score :: 0.7726886555858299
# ======
# The Model_Test_Score ::0.7101213267851018
# ======
# The Model_Fetures :: 13
# ======
# The MAE :: 3.7711251298538304
# ======
# The MSE :: 28.51184078561868
# ======
# The Mid_A_E :: 2.8037303019978808
# =======
# The R2_Score :: 0.7101213267851018

# %% [markdown]
# * Changing parameters

# %%
for i in range(50 , 500 , 50) :
    Random_Forest_reg = RandomForestRegressor(n_estimators=i , random_state =44 , max_depth =5)
    Random_Forest_reg.fit(X_train , y_train)
    Model_Train_Score = Random_Forest_reg.score( X_train , y_train)
    Model_Test_Score = Random_Forest_reg.score( X_test , y_test)
    Model_Fetures = Random_Forest_reg.n_features_
    y_pred = Random_Forest_reg.predict(X_test)

    # Computing Model Accuracy

    MAE = mean_absolute_error( y_test , y_pred , multioutput="uniform_average")
    MSE = mean_squared_error(y_test , y_pred, multioutput="uniform_average")
    Mid_A_E = median_absolute_error(y_test , y_pred)
    R2_Score = r2_score(y_test , y_pred)

    print(f"The Estimator_Value :: {i}\n=====\
    The Model_Train_Score :: {Model_Train_Score}\n======\nThe Model_Test_Score ::\
    {Model_Test_Score}\n======\nThe Model_Fetures :: {Model_Fetures}\n======\nThe MAE :: {MAE}\n======\n\
The MSE :: {MSE}\n======\nThe Mid_A_E :: {Mid_A_E}\n=======\nThe R2_Score :: {R2_Score}\n*********************************\n")
# Out:
# The Estimator_Value :: 50
# =====    The Model_Train_Score :: 0.9388553411190513
# ======
# The Model_Test_Score ::    0.8680065308293778
# ======
# The Model_Fetures :: 13
# ======
# The MAE :: 2.6324760997420196
# ======
# The MSE :: 12.982592806833734
# ======
# The Mid_A_E :: 1.9302981371934838
# =======
# The R2_Score :: 0.8680065308293778
# *********************************
#
# The Estimator_Value :: 100
# =====    The Model_Train_Score :: 0.9413955073847984
# ======
# The Model_Test_Score ::    0.8662464794290374
# ======
# The Model_Fetures :: 13
# ======
# The MAE :: 2.680815039672683
# ======
# The MSE :: 13.155707664661895
# ======
# The Mid_A_E :: 1.9855286348632504
# =======
# The R2_Score :: 0.8662464794290374
# *********************************
#
# The Estimator_Value :: 150
# =====    The Model_Train_Score :: 0.9410884524602627
# ======
# The Model_Test_Score ::    0.8621454954333864
# ======
# The Model_Fetures :: 13
# ======
# The MAE :: 2.713938415204873
# ======
# The MSE :: 13.559071601206796
# ======
# The Mid_A_E :: 1.9578684734739298
# =======
# The R2_Score :: 0.8621454954333864
# *********************************
#
# The Estimator_Value :: 200
# =====    The Model_Train_Score :: 0.9407481176350426
# ======
# The Model_Test_Score ::    0.8611064368640714
# ======
# The Model_Fetures :: 13
# ======
# The MAE :: 2.7157049172055325
# ======
# The MSE :: 13.661271159962464
# ======
# The Mid_A_E :: 1.9157933871235997
# =======
# The R2_Score :: 0.8611064368640714
# *********************************
#
# The Estimator_Value :: 250
# =====    The Model_Train_Score :: 0.9411879209380527
# ======
# The Model_Test_Score ::    0.8607514581273871
# ======
# The Model_Fetures :: 13
# ======
# The MAE :: 2.7205584104448115
# ======
# The MSE :: 13.69618610251541
# ======
# The Mid_A_E :: 1.9366315444372706
# =======
# The R2_Score :: 0.8607514581273871
# *********************************
#
# The Estimator_Value :: 300
# =====    The Model_Train_Score :: 0.9403701186645312
# ======
# The Model_Test_Score ::    0.8608067784017995
# ======
# The Model_Fetures :: 13
# ======
# The MAE :: 2.7195367901138354
# ======
# The MSE :: 13.690744919696508
# ======
# The Mid_A_E :: 1.9538827261219254
# =======
# The R2_Score :: 0.8608067784017995
# *********************************
#
# The Estimator_Value :: 350
# =====    The Model_Train_Score :: 0.9402681793979849
# ======
# The Model_Test_Score ::    0.8596000846050256
# ======
# The Model_Fetures :: 13
# ======
# The MAE :: 2.728802190377815
# ======
# The MSE :: 13.809432717695039
# ======
# The Mid_A_E :: 1.9522747711983648
# =======
# The R2_Score :: 0.8596000846050256
# *********************************
#
# The Estimator_Value :: 400
# =====    The Model_Train_Score :: 0.9401239146422389
# ======
# The Model_Test_Score ::    0.8597205481589723
# ======
# The Model_Fetures :: 13
# ======
# The MAE :: 2.7268160431412403
# ======
# The MSE :: 13.797584182469915
# ======
# The Mid_A_E :: 1.9453962688990583
# =======
# The R2_Score :: 0.8597205481589723
# *********************************
#
# The Estimator_Value :: 450
# =====    The Model_Train_Score :: 0.9394724005298276
# ======
# The Model_Test_Score ::    0.8596791752562059
# ======
# The Model_Fetures :: 13
# ======
# The MAE :: 2.7270698367065025
# ======
# The MSE :: 13.801653531909922
# ======
# The Mid_A_E :: 1.9400431749130824
# =======
# The R2_Score :: 0.8596791752562059
# *********************************
