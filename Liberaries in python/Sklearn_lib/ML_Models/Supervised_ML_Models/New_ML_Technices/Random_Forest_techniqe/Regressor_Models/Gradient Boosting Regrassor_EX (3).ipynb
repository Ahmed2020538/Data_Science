# %%
from sklearn.metrics import mean_squared_error
from sklearn.datasets import make_friedman1
from sklearn.ensemble import GradientBoostingRegressor

X, y = make_friedman1(n_samples=1200, random_state=0, noise=1.0)
X_train = X[:200]
X_test  = X[200:]
y_train = y[:200]
y_test  = y[200:]


est = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1,max_depth=1, random_state=0, loss='ls').fit(X_train, y_train)
mean_squared_error(y_test, est.predict(X_test))

est.score(X_train,y_train)

y_pred = est.predict(X_test)


###########################################################################

for g in range(100,2000 , 100):
    est = GradientBoostingRegressor(n_estimators=g, learning_rate=0.1,max_depth=1, random_state=0, loss='ls').fit(X_train, y_train)
    score = est.score(X_test, y_test)
    y_pred = est.predict(X_test)
    print('MSE for ' , g , ' estimators is ' , mean_squared_error(y_test, y_pred))
    print('Score for ',g,' estimators is ',score)
    print('======================================')
# Out:
# MSE for  100  estimators is  5.009154859960321
# Score for  100  estimators is  0.8058912110043196
# ======================================
# MSE for  200  estimators is  3.840234741105356
# Score for  200  estimators is  0.8511878079447107
# ======================================
# MSE for  300  estimators is  3.6697893021388
# Score for  300  estimators is  0.8577927061106855
# ======================================
# MSE for  400  estimators is  3.6350117462916587
# Score for  400  estimators is  0.8591403644359806
# ======================================
# MSE for  500  estimators is  3.68470362541445
# Score for  500  estimators is  0.8572147640604473
# ======================================
# MSE for  600  estimators is  3.7136880923803433
# Score for  600  estimators is  0.8560915925994478
# ======================================
# MSE for  700  estimators is  3.776042208884316
# Score for  700  estimators is  0.8536753203176245
# ======================================
# MSE for  800  estimators is  3.8298677453542993
# Score for  800  estimators is  0.8515895373875049
# ======================================
# MSE for  900  estimators is  3.873451500607845
# Score for  900  estimators is  0.84990063173602
# ======================================
# MSE for  1000  estimators is  3.920973271689575
# Score for  1000  estimators is  0.8480591247965285
# ======================================
# MSE for  1100  estimators is  3.9624747018683864
# Score for  1100  estimators is  0.8464509109203733
# ======================================
# MSE for  1200  estimators is  4.00461481624067
# Score for  1200  estimators is  0.8448179475168406
# ======================================
# MSE for  1300  estimators is  4.042645497832264
# Score for  1300  estimators is  0.8433442279464132
# ======================================
# MSE for  1400  estimators is  4.092761319473699
# Score for  1400  estimators is  0.8414021994565174
# ======================================
# MSE for  1500  estimators is  4.121539170176794
# Score for  1500  estimators is  0.8402870345422668
# ======================================
# MSE for  1600  estimators is  4.167980152757277
# Score for  1600  estimators is  0.8384874090284853
# ======================================
# MSE for  1700  estimators is  4.1959243957707
# Score for  1700  estimators is  0.8374045470842293
# ======================================
# MSE for  1800  estimators is  4.243106422734152
# Score for  1800  estimators is  0.8355762055032087
# ======================================
# MSE for  1900  estimators is  4.281020601858523
# Score for  1900  estimators is  0.8341070004973056
# ======================================
