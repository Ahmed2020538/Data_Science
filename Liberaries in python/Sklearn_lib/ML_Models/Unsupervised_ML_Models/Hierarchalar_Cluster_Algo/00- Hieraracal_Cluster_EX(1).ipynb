# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("data.csv")
df
# Out:
#              0         1         2         3         4         5         6  \
# 0    -2.084839 -0.471673 -0.955542 -0.567288 -0.953226 -1.510386  0.921728
# 1     0.003700 -0.999118  0.202003  1.612001 -0.375642  0.378518  0.113693
# 2    -1.456240  0.483522 -0.508605 -0.316406 -1.695560 -1.943310  0.299486
# 3    -1.595524 -0.219744  1.039403  0.381587  0.109094 -0.155068  0.156054
# 4     0.995277 -1.517259 -0.101198  1.415742 -0.054356  0.611216  0.196938
# ...        ...       ...       ...       ...       ...       ...       ...
# 1304 -0.862703  0.104828  1.984113 -2.026618 -1.723234  1.355618  0.019176
# 1305  0.299519  2.404711 -0.473917  0.539437  0.144996  1.079460 -0.593131
# 1306  1.983708 -2.251345 -0.891493  0.934429  0.553115  1.194912  0.344667
# 1307  0.369343  3.529447 -0.542355 -1.130391  0.468369 -0.998843  0.550265
# 1308 -2.118941 -0.456731 -1.179383 -0.667595 -1.091675 -1.680951  0.895348
#
#              7
# 0     0.437954
# 1     1.718011
# 2     0.147370
# 3     0.007314
# 4     0.641809
# ...        ...
# 1304  0.361044
# 1305  0.062784
# 1306 -1.039349
# 1307  0.041131
# 1308  0.496857
#
# [1309 rows x 8 columns]

# %%
X = df.iloc[ : , [3 , 4]].values

# %%
Aglom_Model = AgglomerativeClustering(n_clusters=10 , affinity="euclidean" , linkage="ward")
Aglom_Model.fit(X)
# Out:
# AgglomerativeClustering(n_clusters=10)

# %%
sns.set(rc = {"figure.figsize" : [60 , 40]} , font_scale = 6.7)
plt.figure(figsize=[60,40])
dndro_gram = sch.dendrogram(sch.linkage(X , method = "ward"))
plt.title("The Dndrogram of data")
plt.xlabel("Clusters")
plt.ylabel("euclidean")
plt.xticks(rotation = 90)
plt.show()

# %%
y_hc = Aglom_Model.fit_predict(X)

# %%
y_hc[:50]
# Out:
# array([4, 3, 4, 7, 3, 1, 8, 7, 7, 1, 0, 7, 7, 3, 1, 7, 4, 4, 3, 8, 4, 2,
#        7, 4, 3, 7, 7, 4, 1, 5, 7, 1, 3, 1, 5, 4, 1, 3, 1, 0, 7, 0, 7, 3,
#        7, 1, 4, 5, 7, 3], dtype=int64)

# %%
sns.set(rc = {"figure.figsize" : [20 , 10]} , font_scale = 2)
plt.scatter(X[y_hc == 0, 0], X[y_hc == 0, 1], s = 10, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_hc == 1, 0], X[y_hc == 1, 1], s = 10, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_hc == 2, 0], X[y_hc == 2, 1], s = 10, c = 'green', label = 'Cluster 3')
plt.scatter(X[y_hc == 3, 0], X[y_hc == 3, 1], s = 10, c = 'cyan', label = 'Cluster 4')
plt.scatter(X[y_hc == 4, 0], X[y_hc == 4, 1], s = 10, c = 'magenta', label = 'Cluster 5')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %%
plt.scatter(X[: , 0] , X[: , 1] , c = y_hc , cmap = "viridis")
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
# Out:
# No handles with labels found to put in legend.
