# %% [markdown]
# # date_range  Func

# %%
import pandas as pd 

path = "E:\\Data Rows\\Code B\\DateRange_data.txt"

DF =pd.read_csv(path )
DF
# Out:
#          Date    Open    High     Low   Close    Volume
# 0    1-Jun-17  153.17  153.33  152.22  153.18  16404088
# 1    2-Jun-17  153.58  155.45  152.89  155.45  27770715
# 2    5-Jun-17  154.34  154.45  153.46  153.93  25331662
# 3    6-Jun-17  153.90  155.81  153.78  154.45  26624926
# 4    7-Jun-17  155.02  155.98  154.48  155.37  21069647
# 5    8-Jun-17  155.25  155.54  154.40  154.99  21250798
# 6    9-Jun-17  155.19  155.19  146.02  148.98  64882657
# 7   12-Jun-17  145.74  146.09  142.51  145.42  72307330
# 8   13-Jun-17  147.16  147.45  145.15  146.59  34165445
# 9   14-Jun-17  147.50  147.50  143.84  145.16  31531232
# 10  15-Jun-17  143.32  144.48  142.21  144.29  32165373
# 11  16-Jun-17  143.78  144.50  142.20  142.27  50361093
# 12  19-Jun-17  143.66  146.74  143.66  146.34  32541404
# 13  20-Jun-17  146.87  146.87  144.94  145.01  24900073
# 14  21-Jun-17  145.52  146.07  144.61  145.87  21265751
# 15  22-Jun-17  145.77  146.70  145.12  145.63  19106294
# ...

# %%
DF.index
# Out:
# RangeIndex(start=0, stop=22, step=1)

# %%
import pandas as pd 

path = "E:\\Data Rows\\Code B\\DateRange_data.txt"

DF =pd.read_csv(path , parse_dates=["Date"] , index_col="Date" )
DF
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-19  143.66  146.74  143.66  146.34  32541404
# 2017-06-20  146.87  146.87  144.94  145.01  24900073
# 2017-06-21  145.52  146.07  144.61  145.87  21265751
# 2017-06-22  145.77  146.70  145.12  145.63  19106294
# 2017-06-23  145.13  147.16  145.11  146.28  35439389
# ...

# %%
DF.index
# Out:
# DatetimeIndex(['2017-06-01', '2017-06-02', '2017-06-05', '2017-06-06',
#                '2017-06-07', '2017-06-08', '2017-06-09', '2017-06-12',
#                '2017-06-13', '2017-06-14', '2017-06-15', '2017-06-16',
#                '2017-06-19', '2017-06-20', '2017-06-21', '2017-06-22',
#                '2017-06-23', '2017-06-26', '2017-06-27', '2017-06-28',
#                '2017-06-29', '2017-06-30'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
R_DF = pd.date_range( start = "2017-06-10"  , end = "2017-06-29" , freq="D")

R_DF
# Out:
# DatetimeIndex(['2017-06-10', '2017-06-11', '2017-06-12', '2017-06-13',
#                '2017-06-14', '2017-06-15', '2017-06-16', '2017-06-17',
#                '2017-06-18', '2017-06-19', '2017-06-20', '2017-06-21',
#                '2017-06-22', '2017-06-23', '2017-06-24', '2017-06-25',
#                '2017-06-26', '2017-06-27', '2017-06-28', '2017-06-29'],
#               dtype='datetime64[ns]', freq='D')

# %%
R_DF = pd.date_range( start = "2017-06-10"  , periods=10 , freq="D")

R_DF
# Out:
# DatetimeIndex(['2017-06-10', '2017-06-11', '2017-06-12', '2017-06-13',
#                '2017-06-14', '2017-06-15', '2017-06-16', '2017-06-17',
#                '2017-06-18', '2017-06-19'],
#               dtype='datetime64[ns]', freq='D')

# %%
R_DF = pd.date_range( start = "2017-06-10"  , end = "2017-06-29" , freq="W")

R_DF
# Out:
# DatetimeIndex(['2017-06-11', '2017-06-18', '2017-06-25'], dtype='datetime64[ns]', freq='W-SUN')

# %%
R_DF = pd.date_range( start = "2017-06-10"  , periods=10, freq="W")

R_DF
# Out:
# DatetimeIndex(['2017-06-11', '2017-06-18', '2017-06-25', '2017-07-02',
#                '2017-07-09', '2017-07-16', '2017-07-23', '2017-07-30',
#                '2017-08-06', '2017-08-13'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %% [markdown]
#  # To Filling Missing Data Values

# %%
DF.asfreq( "D" , method= "ffill" )
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-03  153.58  155.45  152.89  155.45  27770715
# 2017-06-04  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-10  155.19  155.19  146.02  148.98  64882657
# 2017-06-11  155.19  155.19  146.02  148.98  64882657
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-17  143.78  144.50  142.20  142.27  50361093
# ...

# %%
DF.asfreq( "D" , method= "pad" )
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-03  153.58  155.45  152.89  155.45  27770715
# 2017-06-04  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-10  155.19  155.19  146.02  148.98  64882657
# 2017-06-11  155.19  155.19  146.02  148.98  64882657
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-17  143.78  144.50  142.20  142.27  50361093
# ...

# %%
DF.asfreq( "W" , method= "ffill" )
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-06-04  153.58  155.45  152.89  155.45  27770715
# 2017-06-11  155.19  155.19  146.02  148.98  64882657
# 2017-06-18  143.78  144.50  142.20  142.27  50361093
# 2017-06-25  145.13  147.16  145.11  146.28  35439389

# %%
DF.asfreq( "W" , method= "pad" )
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-06-04  153.58  155.45  152.89  155.45  27770715
# 2017-06-11  155.19  155.19  146.02  148.98  64882657
# 2017-06-18  143.78  144.50  142.20  142.27  50361093
# 2017-06-25  145.13  147.16  145.11  146.28  35439389

# %%
DF.asfreq( "D" , method= "bfill" )
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-03  154.34  154.45  153.46  153.93  25331662
# 2017-06-04  154.34  154.45  153.46  153.93  25331662
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-10  145.74  146.09  142.51  145.42  72307330
# 2017-06-11  145.74  146.09  142.51  145.42  72307330
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-17  143.66  146.74  143.66  146.34  32541404
# ...

# %%
DF.asfreq( "D" , method= "backfill" )
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-03  154.34  154.45  153.46  153.93  25331662
# 2017-06-04  154.34  154.45  153.46  153.93  25331662
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-10  145.74  146.09  142.51  145.42  72307330
# 2017-06-11  145.74  146.09  142.51  145.42  72307330
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-17  143.66  146.74  143.66  146.34  32541404
# ...

# %%
DF.asfreq( "W" , method= "backfill" )
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-06-04  154.34  154.45  153.46  153.93  25331662
# 2017-06-11  145.74  146.09  142.51  145.42  72307330
# 2017-06-18  143.66  146.74  143.66  146.34  32541404
# 2017-06-25  147.17  148.28  145.38  145.82  25692361

# %%
DF.asfreq( "W" , method= "bfill" )
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-06-04  154.34  154.45  153.46  153.93  25331662
# 2017-06-11  145.74  146.09  142.51  145.42  72307330
# 2017-06-18  143.66  146.74  143.66  146.34  32541404
# 2017-06-25  147.17  148.28  145.38  145.82  25692361

# %%
DF.plot()

# %%
DF.plot( kind = "bar")

# %%
DF.Close.plot()

# %%
DF.Close.plot( kind = "bar")

# %%
DF.index
# Out:
# DatetimeIndex(['2017-06-01', '2017-06-02', '2017-06-05', '2017-06-06',
#                '2017-06-07', '2017-06-08', '2017-06-09', '2017-06-12',
#                '2017-06-13', '2017-06-14', '2017-06-15', '2017-06-16',
#                '2017-06-19', '2017-06-20', '2017-06-21', '2017-06-22',
#                '2017-06-23', '2017-06-26', '2017-06-27', '2017-06-28',
#                '2017-06-29', '2017-06-30'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
DF.set_index ( R_DF , inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-8bcd4207a3b8> in <module>
# ----> 1 DF.set_index ( R_DF , inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4440                     "Length mismatch: Expected {len_self} rows, "
#    4441                     "received array of length {len_col}".format(
# -> 4442                         len_self=len(self), len_col=len(arrays[-1])
#    4443                     )
#    4444                 )
#
# ValueError: Length mismatch: Expected 22 rows, received array of length 10
