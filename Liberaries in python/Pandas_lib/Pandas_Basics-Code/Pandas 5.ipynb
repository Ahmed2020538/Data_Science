# %%
import pandas as pd

path = "E:\\Data Rows\\Code B\\Weather data.txt"
D_F =pd.read_csv(path)
D_F
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %% [markdown]
# # Replace Func

# %% [markdown]
# # 1_Replace Single Value

# %%
H_D_F = D_F.replace(-99999 , 100000)
H_D_F
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       100000          7  Sunny
# 2  1/3/2017           28     100000   Snow
# 3  1/4/2017       100000          7      0
# 4  1/5/2017           32     100000   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %% [markdown]
# # 2 _Replace Multi Values

# %%
import pandas as pd

path = "E:\\Data Rows\\Code B\\Weather data.txt"
D_F =pd.read_csv(path)
D_F
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
H_D_F = D_F.replace([-99999 ,5,"Rain"] , 100000)
H_D_F
# Out:
#         day  temperature  windspeed   event
# 0  1/1/2017           32          6  100000
# 1  1/2/2017       100000          7   Sunny
# 2  1/3/2017           28     100000    Snow
# 3  1/4/2017       100000          7       0
# 4  1/5/2017           32     100000  100000
# 5  1/6/2017           31          2   Sunny
# 6  1/6/2017           34     100000       0

# %% [markdown]
# # 3 _ Replace list of Values By List Values

# %%
import pandas as pd

path = "E:\\Data Rows\\Code B\\Weather data.txt"
D_F =pd.read_csv(path)
D_F
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
H_D_F = D_F.replace([-99999 ,7,"0"] , [100000 , 100 ,"Good"])
H_D_F
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       100000        100  Sunny
# 2  1/3/2017           28     100000   Snow
# 3  1/4/2017       100000        100   Good
# 4  1/5/2017           32     100000   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5   Good

# %% [markdown]
# # 4_ Replace Special Values in columns by single value

# %%
import pandas as pd
import numpy as np

path = "E:\\Data Rows\\Code B\\Weather data.txt"
D_F =pd.read_csv(path)
D_F
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
H_D_F = D_F.replace({"temperature" :-99999 ,"windspeed" : 7 , "event" :"0" }  ,np.nan)
H_D_F
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        NaN  Sunny
# 2  1/3/2017         28.0   -99999.0   Snow
# 3  1/4/2017          NaN        NaN    NaN
# 4  1/5/2017         32.0   -99999.0   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0    NaN

# %% [markdown]
# # 5_ Replace Special Values in columns by diff value

# %%
import pandas as pd
import numpy as np

path = "E:\\Data Rows\\Code B\\Weather data.txt"
D_F =pd.read_csv(path)
D_F
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
H_D_F = D_F.replace({-99999 : 100000 , 7 : np.nan , "0" : "GOOd"})
H_D_F
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017     100000.0        NaN  Sunny
# 2  1/3/2017         28.0   100000.0   Snow
# 3  1/4/2017     100000.0        NaN   GOOd
# 4  1/5/2017         32.0   100000.0   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0   GOOd

# %% [markdown]
# # 6_ Replace any Char vaqlues

# %%
import pandas as pd
import numpy as np

path = "E:\\Data Rows\\Code B\\Weather data.txt"
D_F =pd.read_csv(path)
D_F
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
H_D_F = D_F.replace("[A-Za-z]" , " done " , regex=True)
H_D_F
# Out:
#         day  temperature  windspeed                           event
# 0  1/1/2017           32          6         done  done  done  done
# 1  1/2/2017       -99999          7   done  done  done  done  done
# 2  1/3/2017           28     -99999         done  done  done  done
# 3  1/4/2017       -99999          7                               0
# 4  1/5/2017           32     -99999         done  done  done  done
# 5  1/6/2017           31          2   done  done  done  done  done
# 6  1/6/2017           34          5                               0

# %% [markdown]
# # 7_ Replace Special Char Values

# %%
import pandas as pd
import numpy as np

path = "E:\\Data Rows\\Code B\\Weather data.txt"
D_F =pd.read_csv(path)
D_F
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
H_D_F = D_F.replace({"temperature" : -99999 , "event" : "[A-Za-z]"}, "done" , regex=True )
H_D_F
# Out:
#         day temperature  windspeed                 event
# 0  1/1/2017          32          6      donedonedonedone
# 1  1/2/2017        done          7  donedonedonedonedone
# 2  1/3/2017          28     -99999      donedonedonedone
# 3  1/4/2017        done          7                     0
# 4  1/5/2017          32     -99999      donedonedonedone
# 5  1/6/2017          31          2  donedonedonedonedone
# 6  1/6/2017          34          5                     0
