# %% [markdown]
# # To Head Rows

# %% [markdown]
# # 1 _ using header parameter

# %%
import pandas as pd

path = "E:\\Data Rows\\Code B\\Stock_data_Csv.txt"

D_F = pd.read_csv(path )

D_F
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
D_F = pd.read_csv(path , header= 1) 
D_F
# Out:
#   GOOGL          27.82   87   845     larry page
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata

# %%
D_F = pd.read_csv(path , header= 2) 
D_F
# Out:
#     WMT           4.61  484    65           n.a.
# 0  MSFT             -1   85    64     bill gates
# 1  RIL   not available   50  1023  mukesh ambani
# 2  TATA            5.6   -1  n.a.     ratan tata

# %% [markdown]
# # 2  _ using skiprows

# %%
import pandas as pd

path = "E:\\Data Rows\\Code B\\Stock_data_Csv.txt"

D_F = pd.read_csv(path )

D_F
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
D_F = pd.read_csv(path , skiprows= 1) 
D_F
# Out:
#   GOOGL          27.82   87   845     larry page
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata

# %%
D_F = pd.read_csv(path , skiprows= 2) 
D_F
# Out:
#     WMT           4.61  484    65           n.a.
# 0  MSFT             -1   85    64     bill gates
# 1  RIL   not available   50  1023  mukesh ambani
# 2  TATA            5.6   -1  n.a.     ratan tata

# %% [markdown]
# # Addition single row

# %%
import pandas as pd

path = "E:\\Data Rows\\Code B\\Stock_data_Csv.txt"

D_F = pd.read_csv(path )

D_F
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
D_F = pd.read_csv(path , names =["Sites" , "Epps" ,"Renie" , "Prices" , "People"] )
D_F
# Out:
#      Sites           Epps    Renie Prices         People
# 0  tickers            eps  revenue  price         people
# 1    GOOGL          27.82       87    845     larry page
# 2      WMT           4.61      484     65           n.a.
# 3     MSFT             -1       85     64     bill gates
# 4     RIL   not available       50   1023  mukesh ambani
# 5     TATA            5.6       -1   n.a.     ratan tata

# %% [markdown]
# # To print Num of Rows

# %%
import pandas as pd

path = "E:\\Data Rows\\Code B\\Stock_data_Csv.txt"

D_F = pd.read_csv(path )

D_F
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
D_F = pd.read_csv(path , nrows=3)
D_F
# Out:
#   tickers    eps  revenue  price      people
# 0   GOOGL  27.82       87    845  larry page
# 1     WMT   4.61      484     65        n.a.
# 2    MSFT  -1.00       85     64  bill gates

# %% [markdown]
# # Replece Values In DataFrame All

# %%
import pandas as pd

path = "E:\\Data Rows\\Code B\\Stock_data_Csv.txt"

D_F = pd.read_csv(path )

D_F
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
D_F = pd.read_csv(path , na_values=["n.a." ,"not available"])
D_F
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82       87   845.0     larry page
# 1     WMT   4.61      484    65.0            NaN
# 2    MSFT  -1.00       85    64.0     bill gates
# 3    RIL     NaN       50  1023.0  mukesh ambani
# 4    TATA   5.60       -1     NaN     ratan tata

# %% [markdown]
# # Replace Special Values

# %%
import pandas as pd

path = "E:\\Data Rows\\Code B\\Stock_data_Csv.txt"

D_F = pd.read_csv(path )

D_F
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
D_F = pd.read_csv(path , na_values={"eps" : [-1 ,"not available" ] , "revenue" :[-1 ,484],
                                    "price" : ["n.a."] ,"people" : ["n.a."]})
D_F
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61      NaN    65.0            NaN
# 2    MSFT    NaN     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %% [markdown]
#  # Transform DataFrame File

# %% [markdown]
# # 1 _ To_Csv_File

# %%
import pandas as pd

path = "E:\\Data Rows\\Code B\\Stock_data_Csv.txt"

D_F = pd.read_csv(path )

D_F
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df = D_F.to_csv("Stock_data_Csv")
df

# %%
dff= D_F.to_excel("Stock_data_Csv" ,name_sheet ="Sheet1")

dff
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in __new__(cls, path, engine, **kwargs)
#     629                 try:
# --> 630                     engine = config.get_option("io.excel.{ext}.writer".format(ext=ext))
#     631                     if engine == "auto":
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_config\config.py in __call__(self, *args, **kwds)
#     232     def __call__(self, *args, **kwds):
# --> 233         return self.__func__(*args, **kwds)
#     234
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_config\config.py in _get_option(pat, silent)
#     101 def _get_option(pat, silent=False):
# --> 102     key = _get_single_key(pat, silent)
#     103
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_config\config.py in _get_single_key(pat, silent)
# ...
