# %% [markdown]
# # 1 _ Stack Func in pandas  use to Reshapeb DataFramr

# %%
import pandas as pd

path = "E:\\Data Rows\\Code B\\Un_Stack_data.txt"

DF = pd.read_csv( path)
DF
# Out:
#                                                                                                                                                               Price                   Price to earnings ratio (P/E)
#        Company             Facebook  Google       Microsoft                                      Facebook                                                  Google
#        2017-06-05         155           955          66                                                             37.10                                      32.0                                                   NaN
#       2017-06-06          150          987           69                                               36.98                                                    31.3                                                   NaN
# ...

# %%
S_df1 = DF.stack()
S_df1
# Out:
#        Company              Facebook   Google        Microsoft                                       Facebook                                                     Price                                                 Google
#                                                                                                                                                       Price to earnings ratio (P/E)
#        2017-06-05          155            955           66                                                              37.10                                     Price                                                     32.0
#       2017-06-06           150           987            69                                                36.98                                                   Price                                                     31.3
# ...

# %%
S_df2 = DF.stack(level=0)
S_df2
# Out:
#        Company              Facebook   Google        Microsoft                                       Facebook                                                     Price                                                 Google
#                                                                                                                                                       Price to earnings ratio (P/E)
#        2017-06-05          155            955           66                                                              37.10                                     Price                                                     32.0
#       2017-06-06           150           987            69                                                36.98                                                   Price                                                     31.3
# ...

# %%
S_df2 = DF.stack(level=0 , dropna= True)   # Remove any Row include NaN Value
S_df2
# Out:
#        Company              Facebook   Google        Microsoft                                       Facebook                                                     Price                                                 Google
#                                                                                                                                                       Price to earnings ratio (P/E)
#        2017-06-05          155            955           66                                                              37.10                                     Price                                                     32.0
#       2017-06-06           150           987            69                                                36.98                                                   Price                                                     31.3
# ...

# %% [markdown]
# # 2_ Unstack Func

# %%
U_S_DF = DF.unstack()

U_S_DF
# Out:
#                                                                                                              Price     ...                Price to earnings ratio (P/E)
#                                                                                                                   NaN  ...                                 Facebook
#             30.11    NaN             NaN         NaN                                                              NaN  ...                                                NaN
#             30.31    NaN             NaN         NaN                                                              NaN  ...                                                NaN
#             30.46    NaN             NaN         NaN                                                              NaN  ...                                                NaN
# ...
