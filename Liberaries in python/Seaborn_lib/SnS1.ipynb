# %% [markdown]
# # 1 _ import Liberaries
# # 2 _ load data
# # 3 _ Statistical describrtive

# %%
import pandas as pd

import seaborn as sns

data = pd.read_excel("F:\\patition E\\Data Rows\\sales1.xls")

print(data.head(20))

print(data.describe())
# Out:
#     Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0        1         3 2010-10-13            Low               6   261.5400
# 1        2         6 2012-02-20  Not Specified               2     6.9300
# 2        3        32 2011-07-15           High              26  2808.0800
# 3        4        32 2011-07-15           High              24  1761.4000
# 4        5        32 2011-07-15           High              23   160.2335
# 5        6        32 2011-07-15           High              15   140.5600
# 6        7        35 2011-10-22  Not Specified              30   288.5600
# 7        8        35 2011-10-22  Not Specified              14  1892.8480
# 8        9        36 2011-11-02       Critical              46  2484.7455
# 9       10        65 2011-03-17       Critical              32  3812.7300
# 10      11        66 2009-01-19            Low              41   108.1500
# 11      12        69 2009-06-03  Not Specified              42  1186.0600
# ...

# %% [markdown]
# # Run Scatter plot

# %%
sns.relplot("Sales" , "Profit" , data = data)

# %% [markdown]
# # Run scatter plot using hue

# %%
sns.relplot("Sales" , "Profit" , data = data , hue = "Order Priority")

# %% [markdown]
# # Run scatter plot using Style

# %%
sns.relplot("Sales" , "Profit" , data = data , hue = "Order Priority" , style = "Order Priority")

# %%
sns.relplot("Sales" , "Profit" , data = data , hue = "Order Priority" , style = "Ship Mode")

# %% [markdown]
# # Run scatter plot using size of  limit disribution

# %%
sns.relplot("Sales" , "Profit" , data = data , hue = "Order Priority" ,size = "Discount"
,style = "Order Priority")

# %% [markdown]
# # Run scatter plot using sizes of points

# %%
sns.relplot("Sales" , "Profit" , data = data , hue = "Order Priority" ,size = "Discount"
,sizes = (50,200),style = "Order Priority")
