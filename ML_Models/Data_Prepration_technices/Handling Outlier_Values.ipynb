# %%
# importing Liberaries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(rc = {"figure.figsize" : [ 10 , 10 ]} , font_scale=1.5)

# %%
df = pd.read_csv("boston_house_prices.csv")
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null int64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null int64
# TAX        506 non-null int64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# MEDV       506 non-null float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# To Detect Outliers We will Visualize data using boxplot and strip_plot ::
sns.boxplot( x = "CRIM" , data = df)
sns.stripplot( x = "CRIM" , data = df  , color="r")

# %% [markdown]
# * From the Result above we found hue numbers of outliers we will replace that Outlier values

# %%
# To Detect Outliers We will Visualize data using boxplot and strip_plot ::
sns.boxplot( x = "ZN" , data = df)
sns.stripplot( x = "ZN" , data = df  , color="r")

# %% [markdown]
# * From the Result above we found hue numbers of outliers we will replace that Outlier values by median_value

# %%
# To Detect Outliers We will Visualize data using boxplot and strip_plot ::
sns.boxplot( x = "INDUS" , data = df)
sns.stripplot( x = "INDUS" , data = df  , color="r")

# %% [markdown]
# * From the Result above we found less numbers of outliers we will drop that Outlier values

# %%
# To Detect Outliers We will Visualize data using boxplot and strip_plot ::
sns.boxplot( x = "CHAS" , data = df)
sns.stripplot( x = "CHAS" , data = df  , color="r")

# %%
# To Detect Outliers We will Visualize data using boxplot and strip_plot ::
sns.boxplot( x = "NOX" , data = df)
sns.stripplot( x = "NOX" , data = df  , color="r")

# %% [markdown]
# * From the Result above we found less numbers of outliers we will drop that Outlier values

# %%
# To Detect Outliers We will Visualize data using boxplot and strip_plot ::
sns.boxplot( x = "RM" , data = df)
sns.stripplot( x = "RM" , data = df  , color="r")

# %% [markdown]
# * From the Result above we found hue numbers of outliers we will replace that Outlier values

# %%
# To Detect Outliers We will Visualize data using boxplot and strip_plot ::
sns.boxplot( x = "AGE" , data = df)
sns.stripplot( x = "AGE" , data = df  , color="r")

# %% [markdown]
# * From the Result above we found less numbers of outliers we will drop that Outlier values

# %%
# To Detect Outliers We will Visualize data using boxplot and strip_plot ::
sns.boxplot( x = "DIS" , data = df)
sns.stripplot( x = "DIS" , data = df  , color="r")

# %% [markdown]
# * From the Result above we found less numbers of outliers we will drop that Outlier values

# %%
# Replace Outliers Using IQR ::
from datasist.structdata import detect_outliers
outliers = detect_outliers(df , 0 , df.columns)
len(outliers)
# Out:
# 238

# %%
df.drop(outliers , inplace=True)

# %%
# To Detect Outliers We will Visualize data using boxplot and strip_plot ::
sns.boxplot( x = "DIS" , data = df)
sns.stripplot( x = "DIS" , data = df  , color="r")

# %%
# To Detect Outliers We will Visualize data using boxplot and strip_plot ::
sns.boxplot( x = "RM" , data = df)
sns.stripplot( x = "RM" , data = df  , color="r")

# %%
# To Detect Outliers We will Visualize data using boxplot and strip_plot ::
sns.boxplot( x = "CRIM" , data = df)
sns.stripplot( x = "CRIM" , data = df  , color="r")

# %%
df = pd.read_csv("boston_house_prices.csv")
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
# To Detect Outliers We will Visualize data using boxplot and strip_plot ::
sns.boxplot( x = "DIS" , data = df)
sns.stripplot( x = "DIS" , data = df  , color="r")

# %%
# Handlling outliers using replace that values by Median_values
from datasist.structdata import detect_outliers
for col in df.columns :
    Outliers = detect_outliers(df , 0 , [col])
    median_col_value = df[col].median()
    df[col].iloc[Outliers]  = median_col_value
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
# To Detect Outliers We will Visualize data using boxplot and strip_plot ::
sns.boxplot( x = "DIS" , data = df)
sns.stripplot( x = "DIS" , data = df  , color="r")

# %%
# To Detect Outliers We will Visualize data using boxplot and strip_plot ::
sns.boxplot( x = "RM" , data = df)
sns.stripplot( x = "RM" , data = df  , color="r")
