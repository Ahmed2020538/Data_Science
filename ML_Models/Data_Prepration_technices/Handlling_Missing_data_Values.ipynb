# %%
# Importing Liberaries Which we will use
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(rc = {"figure.figsize" : [10 , 10]} , font_scale=1.5)
sns.set_palette("viridis")

# %%
# Loding dataset
df = pd.read_csv("wiki4HE.csv" , sep = ";")

# %%
# present head and tail of data to show it
df.head(10)
# Out:
#    AGE  GENDER DOMAIN  PhD YEARSEXP  UNIVERSITY UOC_POSITION OTHER_POSITION  \
# 0   40       0      2    1       14           1            2              ?
# 1   42       0      5    1       18           1            2              ?
# 2   37       0      4    1       13           1            3              ?
# 3   40       0      4    0       13           1            3              ?
# 4   51       0      6    0        8           1            3              ?
# 5   47       0      4    0       17           1            3              ?
# 6   43       0      4    0       11           1            3              ?
# 7   55       0      6    0       12           1            3              ?
# 8   54       0      1    1       14           1            2              ?
# 9   50       0      4    1       25           1            2              ?
#
#   OTHERSTATUS USERWIKI  ... BI2 Inc1 Inc2 Inc3 Inc4 Exp1 Exp2 Exp3 Exp4 Exp5
# ...

# %%
df.tail(10)
# Out:
#      AGE  GENDER DOMAIN  PhD YEARSEXP  UNIVERSITY UOC_POSITION OTHER_POSITION  \
# 903   45       0      6    0       18           2            ?              ?
# 904   34       1      1    1        6           2            ?              ?
# 905   48       0      6    1       21           2            ?              ?
# 906   50       0      6    1        1           2            ?              ?
# 907   52       1      6    1       19           2            ?              ?
# 908   43       0      5    1       21           2            ?              ?
# 909   53       0      6    0       25           2            ?              ?
# 910   39       0      5    1        9           2            ?              ?
# 911   40       0      3    1       10           2            ?              ?
# 912   41       1      3    1       12           2            ?              ?
#
#     OTHERSTATUS USERWIKI  ... BI2 Inc1 Inc2 Inc3 Inc4 Exp1 Exp2 Exp3 Exp4 Exp5
# ...

# %% [markdown]
# * From the result above we will see that there are labels refer to missing data like (?)

# %%
# Present uniqe and value_counts 
for col in df.columns :
    print(f"The Col :: {col}\n\nThe Unique_Values of {col} :: {df[col].unique()}\n\nThe Vaules_count of {col} :: \n\n{df[col].value_counts()}\n-------------------------\n ")
# Out:
# The Col :: AGE
#
# The Unique_Values of AGE :: [40 42 37 51 47 43 55 54 50 48 38 56 44 39 33 36 45 35 41 49 46 34 59 32
#  52 31 62 53 29 30 57 58 63 68 69 24 28 60 26 64 67 65 27 23 25 61]
#
# The Vaules_count of AGE ::
#
# 43    49
# 39    44
# 42    44
# 46    44
# 45    43
# 33    43
# 38    42
# 41    41
# 35    38
# 40    38
# 44    38
# 48    35
# 36    35
# 47    32
# 49    32
# 37    31
# 34    30
# 50    28
# 31    23
# 52    22
# 32    21
# 51    18
# 53    16
# 29    13
# 54    11
# 56    11
# 28    11
# 55    10
# 30     9
# 58     8
# 62     7
# 59     7
# 60     6
# 26     5
# 57     5
# 63     4
# 27     4
# 24     3
# 25     2
# 23     2
# 61     2
# 65     2
# 68     1
# 64     1
# 67     1
# 69     1
# Name: AGE, dtype: int64
# -------------------------
#
# The Col :: GENDER
#
# The Unique_Values of GENDER :: [0 1]
#
# The Vaules_count of GENDER ::
#
# 0    525
# 1    388
# Name: GENDER, dtype: int64
# -------------------------
#
# The Col :: DOMAIN
#
# ...

# %% [markdown]
# * From the result above we will see that there are labels refer to missing data like (?) may found ull valuers like ["?" , "-" "_" ,"no" , "Missing"]

# %%
df = pd.read_csv("wiki4HE.csv" , sep = ";" , na_values=["?"])

# %%
df
# Out:
#      AGE  GENDER  DOMAIN  PhD  YEARSEXP  UNIVERSITY  UOC_POSITION  \
# 0     40       0     2.0    1      14.0           1           2.0
# 1     42       0     5.0    1      18.0           1           2.0
# 2     37       0     4.0    1      13.0           1           3.0
# 3     40       0     4.0    0      13.0           1           3.0
# 4     51       0     6.0    0       8.0           1           3.0
# ..   ...     ...     ...  ...       ...         ...           ...
# 908   43       0     5.0    1      21.0           2           NaN
# 909   53       0     6.0    0      25.0           2           NaN
# 910   39       0     5.0    1       9.0           2           NaN
# 911   40       0     3.0    1      10.0           2           NaN
# 912   41       1     3.0    1      12.0           2           NaN
#
#      OTHER_POSITION  OTHERSTATUS  USERWIKI  ...  BI2  Inc1  Inc2  Inc3  Inc4  \
# 0               NaN          NaN       0.0  ...  3.0   5.0   5.0   5.0   5.0
# ...

# %%
# Identifing Missing data_values
df.isnull().sum()
# Out:
# AGE                 0
# GENDER              0
# DOMAIN              2
# PhD                 0
# YEARSEXP           23
# UNIVERSITY          0
# UOC_POSITION      113
# OTHER_POSITION    261
# OTHERSTATUS       540
# USERWIKI            4
# PU1                 7
# PU2                11
# PU3                 5
# PEU1                4
# PEU2               14
# PEU3               97
# ENJ1                7
# ENJ2               17
# Qu1                 7
# Qu2                10
# Qu3                15
# Qu4                22
# Qu5                29
# Vis1               72
# Vis2              117
# Vis3                8
# Im1                22
# Im2                20
# Im3                57
# SA1                11
# SA2                12
# SA3                11
# Use1               14
# Use2               17
# Use3                9
# Use4               23
# Use5               15
# Pf1                11
# Pf2                 6
# Pf3                14
# JR1                27
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913 entries, 0 to 912
# Data columns (total 53 columns):
# AGE               913 non-null int64
# GENDER            913 non-null int64
# DOMAIN            911 non-null float64
# PhD               913 non-null int64
# YEARSEXP          890 non-null float64
# UNIVERSITY        913 non-null int64
# UOC_POSITION      800 non-null float64
# OTHER_POSITION    652 non-null float64
# OTHERSTATUS       373 non-null float64
# USERWIKI          909 non-null float64
# PU1               906 non-null float64
# PU2               902 non-null float64
# PU3               908 non-null float64
# PEU1              909 non-null float64
# PEU2              899 non-null float64
# PEU3              816 non-null float64
# ENJ1              906 non-null float64
# ENJ2              896 non-null float64
# Qu1               906 non-null float64
# Qu2               903 non-null float64
# Qu3               898 non-null float64
# ...

# %% [markdown]
# * From the result above we can see that all features are Numerical data so that on that case we can solve that problem e::
#      * drop features which it include hue null_values and useless feature Like OTHER_Status
#      * Fill Nan values using mean or median or Mod

# %%
df.columns
# Out:
# Index(['AGE', 'GENDER', 'DOMAIN', 'PhD', 'YEARSEXP', 'UNIVERSITY',
#        'UOC_POSITION', 'OTHER_POSITION', 'OTHERSTATUS', 'USERWIKI', 'PU1',
#        'PU2', 'PU3', 'PEU1', 'PEU2', 'PEU3', 'ENJ1', 'ENJ2', 'Qu1', 'Qu2',
#        'Qu3', 'Qu4', 'Qu5', 'Vis1', 'Vis2', 'Vis3', 'Im1', 'Im2', 'Im3', 'SA1',
#        'SA2', 'SA3', 'Use1', 'Use2', 'Use3', 'Use4', 'Use5', 'Pf1', 'Pf2',
#        'Pf3', 'JR1', 'JR2', 'BI1', 'BI2', 'Inc1', 'Inc2', 'Inc3', 'Inc4',
#        'Exp1', 'Exp2', 'Exp3', 'Exp4', 'Exp5'],
#       dtype='object')

# %%
# drop column which inclue huenum of Null values 
df.drop("OTHERSTATUS" , axis = 1 , inplace = True)

# %% [markdown]
# * From The result we get from exolratory data we can see that all columns are discrete_Numerical_data That means we will use Mod to Fill na data

# %%
for col in df.columns :
    df[col].fillna(df[col].median() , inplace = True )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913 entries, 0 to 912
# Data columns (total 52 columns):
# AGE               913 non-null int64
# GENDER            913 non-null int64
# DOMAIN            913 non-null float64
# PhD               913 non-null int64
# YEARSEXP          913 non-null float64
# UNIVERSITY        913 non-null int64
# UOC_POSITION      913 non-null float64
# OTHER_POSITION    913 non-null float64
# USERWIKI          913 non-null float64
# PU1               913 non-null float64
# PU2               913 non-null float64
# PU3               913 non-null float64
# PEU1              913 non-null float64
# PEU2              913 non-null float64
# PEU3              913 non-null float64
# ENJ1              913 non-null float64
# ENJ2              913 non-null float64
# Qu1               913 non-null float64
# Qu2               913 non-null float64
# Qu3               913 non-null float64
# Qu4               913 non-null float64
# ...

# %%
df.isnull().sum()
# Out:
# AGE               0
# GENDER            0
# DOMAIN            0
# PhD               0
# YEARSEXP          0
# UNIVERSITY        0
# UOC_POSITION      0
# OTHER_POSITION    0
# USERWIKI          0
# PU1               0
# PU2               0
# PU3               0
# PEU1              0
# PEU2              0
# PEU3              0
# ENJ1              0
# ENJ2              0
# Qu1               0
# Qu2               0
# Qu3               0
# Qu4               0
# Qu5               0
# Vis1              0
# Vis2              0
# Vis3              0
# Im1               0
# Im2               0
# Im3               0
# SA1               0
# SA2               0
# SA3               0
# Use1              0
# Use2              0
# Use3              0
# Use4              0
# Use5              0
# Pf1               0
# Pf2               0
# Pf3               0
# JR1               0
# JR2               0
# BI1               0
# BI2               0
# Inc1              0
# Inc2              0
# ...

# %% [markdown]
# # Other Data For Handlling data

# %%
# Loading data
df = pd.read_csv("melb_data.csv")

# %%
# Present head and head data
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
# Suburb           13580 non-null object
# Address          13580 non-null object
# Rooms            13580 non-null int64
# Type             13580 non-null object
# Price            13580 non-null float64
# Method           13580 non-null object
# SellerG          13580 non-null object
# Date             13580 non-null object
# Distance         13580 non-null float64
# Postcode         13580 non-null float64
# Bedroom2         13580 non-null float64
# Bathroom         13580 non-null float64
# Car              13518 non-null float64
# Landsize         13580 non-null float64
# BuildingArea     7130 non-null float64
# YearBuilt        8205 non-null float64
# CouncilArea      12211 non-null object
# Lattitude        13580 non-null float64
# Longtitude       13580 non-null float64
# Regionname       13580 non-null object
# Propertycount    13580 non-null float64
# ...

# %% [markdown]
# * From the result above we can see some Observations ::
#      * We have 13580 samples of data
#      * We have 21 features of data
#      * our target feature is Price
#      * The Date column as dtype Object insted of datetime type
#      * The have some columns we can doing feature engineering in it like ("lati , long , Address , Postcard  ,Date")

# %%
# Handling Date type from Objects into Date_Time
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
# Suburb           13580 non-null object
# Address          13580 non-null object
# Rooms            13580 non-null int64
# Type             13580 non-null object
# Price            13580 non-null float64
# Method           13580 non-null object
# SellerG          13580 non-null object
# Date             13580 non-null datetime64[ns]
# Distance         13580 non-null float64
# Postcode         13580 non-null float64
# Bedroom2         13580 non-null float64
# Bathroom         13580 non-null float64
# Car              13518 non-null float64
# Landsize         13580 non-null float64
# BuildingArea     7130 non-null float64
# YearBuilt        8205 non-null float64
# CouncilArea      12211 non-null object
# Lattitude        13580 non-null float64
# Longtitude       13580 non-null float64
# Regionname       13580 non-null object
# Propertycount    13580 non-null float64
# ...

# %% [markdown]
# # Applying Feature Enginerring technices

# %%
# From Date Feature we can generate years , months , days , hours and mintues

df["Years"]   = df["Date"].dt.year
df["Months"]  = df["Date"].dt.month
df["Days"]    = df["Date"].dt.day
df["Weeks"]   = df["Date"].dt.week
df["Months_name"] = df["Date"].dt.month_name()
df["week_ends"]   = df["Date"].dt.weekday
df["Day_names"]   = df["Date"].dt.day_name()

# %%
df[["Years" , "Months" , "Months_name" , "Weeks" , "week_ends" , "Days" ,"Day_names"]]
# Out:
#        Years  Months Months_name  Weeks  week_ends  Days  Day_names
# 0       2016       3       March     10          5    12   Saturday
# 1       2016       4       April     13          5     2   Saturday
# 2       2017       4       April     14          0     3     Monday
# 3       2017       4       April     14          0     3     Monday
# 4       2016       4       April     14          2     6  Wednesday
# ...      ...     ...         ...    ...        ...   ...        ...
# 13575   2017       8      August     34          5    26   Saturday
# 13576   2017       8      August     34          5    26   Saturday
# 13577   2017       8      August     34          5    26   Saturday
# 13578   2017       8      August     34          5    26   Saturday
# 13579   2017       8      August     34          5    26   Saturday
#
# [13580 rows x 7 columns]

# %%
sns.countplot( x = "Years" ,data = df , palette = "viridis")

# %%
sns.countplot( x = "Post_Class" ,data = df , palette = "viridis" , hue="Years")

# %%
sns.countplot( x = "Months" ,data = df , palette = "viridis")

# %%
sns.countplot( x = "Day_names" ,data = df , palette = "viridis") 
plt.xticks(rotation = 90)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), <a list of 7 Text xticklabel objects>)

# %%
sns.pairplot(df)

# %%
df["Postcode"] = df["Postcode"].apply( lambda x  : int(x))
df[["Postcode"]]
# Out:
#        Postcode
# 0          3067
# 1          3067
# 2          3067
# 3          3067
# 4          3067
# ...         ...
# 13575      3150
# 13576      3016
# 13577      3016
# 13578      3016
# 13579      3013
#
# [13580 rows x 1 columns]

# %%
def Post_type(x) :
    x =str(x)
    if x.endswith(("1" or "2" or "3") ):
        return "Class_A"
    elif x.endswith(("4" or "5" or"6")) :
        return "Class_B"
    elif x.endswith(("7" or "8" or "9" )) :
        return "Class_C"

# %%
df["Post_Class"] = df["Postcode"].apply(Post_type)

# %%
df[["Post_Class"]]
# Out:
#       Post_Class
# 0        Class_C
# 1        Class_C
# 2        Class_C
# 3        Class_C
# 4        Class_C
# ...          ...
# 13575       None
# 13576       None
# 13577       None
# 13578       None
# 13579       None
#
# [13580 rows x 1 columns]

# %%
sns.countplot( x = "Post_Class" , data = df , palette = "viridis")

# %%
# Identifing data corrolation
df.corr()
# Out:
#                   Rooms     Price  Distance  Postcode  Bedroom2  Bathroom  \
# Rooms          1.000000  0.496634  0.294203  0.055303  0.944190  0.592934
# Price          0.496634  1.000000 -0.162522  0.107867  0.475951  0.467038
# Distance       0.294203 -0.162522  1.000000  0.431514  0.295927  0.127155
# Postcode       0.055303  0.107867  0.431514  1.000000  0.060584  0.113664
# Bedroom2       0.944190  0.475951  0.295927  0.060584  1.000000  0.584685
# Bathroom       0.592934  0.467038  0.127155  0.113664  0.584685  1.000000
# Car            0.408483  0.238979  0.262994  0.050289  0.405325  0.322246
# Landsize       0.025678  0.037507  0.025004  0.024558  0.025646  0.037130
# BuildingArea   0.124127  0.090981  0.099481  0.055475  0.122319  0.111933
# YearBuilt     -0.065413 -0.323617  0.246379  0.032863 -0.053319  0.152702
# Lattitude      0.015948 -0.212934 -0.130723 -0.406104  0.015925 -0.070594
# Longtitude     0.100771  0.203656  0.239425  0.445357  0.102238  0.118971
# ...

# %%
sns.heatmap(df.corr() , annot =True )

# %%
# To get the most coorelation data 
k = 10
Con_Matrix = df.corr()
Largst_Correlation = Con_Matrix.nlargest( k , "Price")["Price"].index
Most_Correlation = np.corrcoef(df[Largst_Correlation].values.T)
print(f"The 10 Lagest_coorelation data with Price :: \n{Largst_Correlation}\n\n\
The orrelation :: \n{Most_Correlation}")
# Out:
# The 10 Lagest_coorelation data with Price ::
# Index(['Price', 'Rooms', 'Bedroom2', 'Bathroom', 'Car', 'Longtitude',
#        'Postcode', 'BuildingArea', 'Landsize', 'week_ends'],
#       dtype='object')
#
# The orrelation ::
# [[1.         0.49663368 0.47595103 0.46703818        nan 0.20365579
#   0.10786699        nan 0.03750745 0.03237403]
#  [0.49663368 1.         0.94419027 0.59293408        nan 0.10077145
#   0.05530285        nan 0.02567835 0.0400768 ]
#  [0.47595103 0.94419027 1.         0.58468549        nan 0.10223785
#   0.06058449        nan 0.02564625 0.0384724 ]
#  [0.46703818 0.59293408 0.58468549 1.                nan 0.11897143
#   0.1136643         nan 0.03713036 0.02269351]
#  [       nan        nan        nan        nan        nan        nan
#          nan        nan        nan        nan]
#  [0.20365579 0.10077145 0.10223785 0.11897143        nan 1.
#   0.4453569         nan 0.01083347 0.01635408]
# ...

# %%
sns.heatmap(Con_Matrix )

# %%
sns.heatmap(Most_Correlation , annot=True, xticklabels=Largst_Correlation.values , yticklabels = Largst_Correlation.values)

# %%
# Identifing_Missing_data
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# Years               0
# Months              0
# Days                0
# Weeks               0
# Months_name         0
# week_ends           0
# Day_names           0
# Post_Class       9183
# dtype: int64

# %%
# Present uniqe and value_counts 
for col in df.columns :
    print(f"The Col :: {col}\n\nThe Unique_Values of {col} :: {df[col].unique()}\n\nThe Vaules_count of {col} :: \n\n{df[col].value_counts()}\n-------------------------\n ")
# Out:
# The Col :: Suburb
#
# The Unique_Values of Suburb :: ['Abbotsford' 'Airport West' 'Albert Park' 'Alphington' 'Altona'
#  'Altona North' 'Armadale' 'Ascot Vale' 'Ashburton' 'Ashwood'
#  'Avondale Heights' 'Balaclava' 'Balwyn' 'Balwyn North' 'Bentleigh'
#  'Bentleigh East' 'Box Hill' 'Braybrook' 'Brighton' 'Brighton East'
#  'Brunswick' 'Brunswick West' 'Bulleen' 'Burwood' 'Camberwell'
#  'Canterbury' 'Carlton North' 'Carnegie' 'Caulfield' 'Caulfield North'
#  'Caulfield South' 'Chadstone' 'Clifton Hill' 'Coburg' 'Coburg North'
#  'Collingwood' 'Doncaster' 'Eaglemont' 'Elsternwick' 'Elwood' 'Essendon'
#  'Essendon North' 'Fairfield' 'Fitzroy' 'Fitzroy North' 'Flemington'
#  'Footscray' 'Glen Iris' 'Glenroy' 'Gowanbrae' 'Hadfield' 'Hampton'
#  'Hampton East' 'Hawthorn' 'Heidelberg Heights' 'Heidelberg West'
#  'Hughesdale' 'Ivanhoe' 'Kealba' 'Keilor East' 'Kensington' 'Kew'
#  'Kew East' 'Kooyong' 'Maidstone' 'Malvern' 'Malvern East' 'Maribyrnong'
# ...

# %% [markdown]
# * From the result above we found that ::
#      * car_Col is categorical so that we will drop na values becouse they are less num
#      * CouncilArea and Post_Class col include hue numbers of missing value so that on that case we will fill Becouse if we drop na_values we will Lose lage num of data
#      * YearBuilt and BuildingArea Numerical columns and include hue numbers of missing data so that we will fiil it using median Becouse may we found Outliers data so we cont using mean imputer

# %%
# Solve Car_col_missing data by droping na values
df.dropna(subset=["Car"] , axis = 0 , inplace=True)
# Solve CouncilArea _ cols whiche include hue numbers of null values by filling with mod_value which categorical_data
df['Post_Class'].fillna(df['Post_Class'].mode()[0], inplace=True)
df['CouncilArea'].fillna(df['CouncilArea'].mode()[0], inplace=True)
# Solve YearBuilt and BuildingArea which include hue numbers of null values
Numerical_cols = ["BuildingArea" , "YearBuilt"] 
for col in Numerical_cols :
    df[col].fillna(df[col].median() , inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13518 entries, 0 to 13579
# Data columns (total 29 columns):
# Suburb           13518 non-null object
# Address          13518 non-null object
# Rooms            13518 non-null int64
# Type             13518 non-null object
# Price            13518 non-null float64
# Method           13518 non-null object
# SellerG          13518 non-null object
# Date             13518 non-null datetime64[ns]
# Distance         13518 non-null float64
# Postcode         13518 non-null int64
# Bedroom2         13518 non-null float64
# Bathroom         13518 non-null float64
# Car              13518 non-null float64
# Landsize         13518 non-null float64
# BuildingArea     13518 non-null float64
# YearBuilt        13518 non-null float64
# CouncilArea      13518 non-null object
# Lattitude        13518 non-null float64
# Longtitude       13518 non-null float64
# Regionname       13518 non-null object
# Propertycount    13518 non-null float64
# ...

# %%
df.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# Years            0
# Months           0
# Days             0
# Weeks            0
# Months_name      0
# week_ends        0
# Day_names        0
# Post_Class       0
# dtype: int64

# %% [markdown]
# # Other Methods To Solve Missng data values Using Sklearn

# %%
df = pd.read_csv("melb_data.csv")
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
# Suburb           13580 non-null object
# Address          13580 non-null object
# Rooms            13580 non-null int64
# Type             13580 non-null object
# Price            13580 non-null float64
# Method           13580 non-null object
# SellerG          13580 non-null object
# Date             13580 non-null object
# Distance         13580 non-null float64
# Postcode         13580 non-null float64
# Bedroom2         13580 non-null float64
# Bathroom         13580 non-null float64
# Car              13518 non-null float64
# Landsize         13580 non-null float64
# BuildingArea     7130 non-null float64
# YearBuilt        8205 non-null float64
# CouncilArea      12211 non-null object
# Lattitude        13580 non-null float64
# Longtitude       13580 non-null float64
# Regionname       13580 non-null object
# Propertycount    13580 non-null float64
# ...

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %% [markdown]
# * Imputting Numerical_missing values using Simpleimputer

# %%
from sklearn.impute import SimpleImputer 
imp = SimpleImputer( strategy="median")
df["BuildingArea"] = imp.fit_transform(df[["BuildingArea"]])
imp.statistics_
# Out:
# array([126.])

# %%
from sklearn.impute import SimpleImputer 
imp = SimpleImputer( strategy="median")
df["YearBuilt"] = imp.fit_transform(df[["YearBuilt"]])
imp.statistics_
# Out:
# array([1970.])

# %%
from sklearn.impute import  SimpleImputer
imp = SimpleImputer( strategy="median")
df["BuildingArea"] = imp.fit_transform(df[["BuildingArea"]])
imp.statistics_
# Out:
# array([126.])

# %% [markdown]
# * Imputting Categorical_missing values

# %%
from sklearn.impute import SimpleImputer 
imp = SimpleImputer( strategy="most_frequent")
df["Car"] = imp.fit_transform(df[["Car"]])
imp.statistics_
# Out:
# array([2.])

# %%
from sklearn.impute import SimpleImputer 
imp = SimpleImputer( strategy="most_frequent")
df["CouncilArea"] = imp.fit_transform(df[["CouncilArea"]])
imp.statistics_
# Out:
# array(['Moreland'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
# Suburb           13580 non-null object
# Address          13580 non-null object
# Rooms            13580 non-null int64
# Type             13580 non-null object
# Price            13580 non-null float64
# Method           13580 non-null object
# SellerG          13580 non-null object
# Date             13580 non-null object
# Distance         13580 non-null float64
# Postcode         13580 non-null float64
# Bedroom2         13580 non-null float64
# Bathroom         13580 non-null float64
# Car              13580 non-null float64
# Landsize         13580 non-null float64
# BuildingArea     13580 non-null float64
# YearBuilt        13580 non-null float64
# CouncilArea      13580 non-null object
# Lattitude        13580 non-null float64
# Longtitude       13580 non-null float64
# Regionname       13580 non-null object
# Propertycount    13580 non-null float64
# ...

# %%
df.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
df = pd.read_csv("melb_data.csv")
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
# Suburb           13580 non-null object
# Address          13580 non-null object
# Rooms            13580 non-null int64
# Type             13580 non-null object
# Price            13580 non-null float64
# Method           13580 non-null object
# SellerG          13580 non-null object
# Date             13580 non-null object
# Distance         13580 non-null float64
# Postcode         13580 non-null float64
# Bedroom2         13580 non-null float64
# Bathroom         13580 non-null float64
# Car              13518 non-null float64
# Landsize         13580 non-null float64
# BuildingArea     7130 non-null float64
# YearBuilt        8205 non-null float64
# CouncilArea      12211 non-null object
# Lattitude        13580 non-null float64
# Longtitude       13580 non-null float64
# Regionname       13580 non-null object
# Propertycount    13580 non-null float64
# ...

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %% [markdown]
# * Imputting Numerical_missing values using KNNImputer

# %%
from sklearn.impute import KNNImputer 
imp = SimpleImputer( )
df["YearBuilt"] = imp.fit_transform(df[["YearBuilt"]])
imp.statistics_
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-94-3fa71fb0c89e> in <module>
# ----> 1 from sklearn.impute import KNNImputer
#       2 imp = SimpleImputer( )
#       3 df["YearBuilt"] = imp.fit_transform(df[["YearBuilt"]])
#       4 imp.statistics_
#
# ImportError: cannot import name 'KNNImputer' from 'sklearn.impute' (C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\__init__.py)
