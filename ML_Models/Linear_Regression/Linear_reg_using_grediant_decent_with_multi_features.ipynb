# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = "G:\\Data Field\\D..S..Course\\data.sc.Asem\\data2.txt"
data = pd.read_csv( path , header = None , names = ["Size" , "Rooms" , "Price"])

# %%
data
# Out:
#     Size  Rooms   Price
# 0   2104      3  399900
# 1   1600      3  329900
# 2   2400      3  369000
# 3   1416      2  232000
# 4   3000      4  539900
# 5   1985      4  299900
# 6   1534      3  314900
# 7   1427      3  198999
# 8   1380      3  212000
# 9   1494      3  242500
# 10  1940      4  239999
# 11  2000      3  347000
# 12  1890      3  329999
# 13  4478      5  699900
# 14  1268      3  259900
# 15  2300      4  449900
# 16  1320      2  299900
# 17  1236      3  199900
# 18  2609      4  499998
# 19  3031      4  599000
# 20  1767      3  252900
# 21  1888      2  255000
# 22  1604      3  242900
# 23  1962      4  259900
# 24  3890      3  573900
# 25  1100      3  249900
# 26  1458      3  464500
# 27  2526      3  469000
# 28  2200      3  475000
# 29  2637      3  299900
# 30  1839      2  349900
# 31  1000      1  169900
# 32  2040      4  314900
# 33  3137      3  579900
# 34  1811      4  285900
# 35  1437      3  249900
# 36  1239      3  229900
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of     Size  Rooms   Price
# 0   2104      3  399900
# 1   1600      3  329900
# 2   2400      3  369000
# 3   1416      2  232000
# 4   3000      4  539900
# 5   1985      4  299900
# 6   1534      3  314900
# 7   1427      3  198999
# 8   1380      3  212000
# 9   1494      3  242500
# 10  1940      4  239999
# 11  2000      3  347000
# 12  1890      3  329999
# 13  4478      5  699900
# 14  1268      3  259900
# 15  2300      4  449900
# 16  1320      2  299900
# 17  1236      3  199900
# 18  2609      4  499998
# 19  3031      4  599000
# 20  1767      3  252900
# 21  1888      2  255000
# 22  1604      3  242900
# 23  1962      4  259900
# 24  3890      3  573900
# 25  1100      3  249900
# 26  1458      3  464500
# 27  2526      3  469000
# 28  2200      3  475000
# 29  2637      3  299900
# 30  1839      2  349900
# 31  1000      1  169900
# 32  2040      4  314900
# 33  3137      3  579900
# 34  1811      4  285900
# 35  1437      3  249900
# ...

# %%
data.describe()
# Out:
#               Size      Rooms          Price
# count    47.000000  47.000000      47.000000
# mean   2000.680851   3.170213  340412.659574
# std     794.702354   0.760982  125039.899586
# min     852.000000   1.000000  169900.000000
# 25%    1432.000000   3.000000  249900.000000
# 50%    1888.000000   3.000000  299900.000000
# 75%    2269.000000   4.000000  384450.000000
# max    4478.000000   5.000000  699900.000000

# %% [markdown]
# Rescalling _ data

# %%
data = (data - data.mean()) / data.std()

# %%
data
# Out:
#         Size     Rooms     Price
# 0   0.130010 -0.223675  0.475747
# 1  -0.504190 -0.223675 -0.084074
# 2   0.502476 -0.223675  0.228626
# 3  -0.735723 -1.537767 -0.867025
# 4   1.257476  1.090417  1.595389
# 5  -0.019732  1.090417 -0.323998
# 6  -0.587240 -0.223675 -0.204036
# 7  -0.721881 -0.223675 -1.130948
# 8  -0.781023 -0.223675 -1.026973
# 9  -0.637573 -0.223675 -0.783051
# 10 -0.076357  1.090417 -0.803053
# 11 -0.000857 -0.223675  0.052682
# 12 -0.139273 -0.223675 -0.083283
# 13  3.117292  2.404508  2.874981
# 14 -0.921956 -0.223675 -0.643896
# 15  0.376643  1.090417  0.875619
# 16 -0.856523 -1.537767 -0.323998
# 17 -0.962223 -0.223675 -1.123743
# 18  0.765468  1.090417  1.276275
# 19  1.296484  1.090417  2.068039
# 20 -0.294048 -0.223675 -0.699878
# 21 -0.141790 -1.537767 -0.683083
# 22 -0.499157 -0.223675 -0.779852
# 23 -0.048673  1.090417 -0.643896
# 24  2.377392 -0.223675  1.867303
# 25 -1.133356 -0.223675 -0.723870
# 26 -0.682873 -0.223675  0.992382
# ...

# %%
data.insert( 0 , "Ones" , 1)
data
# Out:
#     Ones      Size     Rooms     Price
# 0      1  0.130010 -0.223675  0.475747
# 1      1 -0.504190 -0.223675 -0.084074
# 2      1  0.502476 -0.223675  0.228626
# 3      1 -0.735723 -1.537767 -0.867025
# 4      1  1.257476  1.090417  1.595389
# 5      1 -0.019732  1.090417 -0.323998
# 6      1 -0.587240 -0.223675 -0.204036
# 7      1 -0.721881 -0.223675 -1.130948
# 8      1 -0.781023 -0.223675 -1.026973
# 9      1 -0.637573 -0.223675 -0.783051
# 10     1 -0.076357  1.090417 -0.803053
# 11     1 -0.000857 -0.223675  0.052682
# 12     1 -0.139273 -0.223675 -0.083283
# 13     1  3.117292  2.404508  2.874981
# 14     1 -0.921956 -0.223675 -0.643896
# 15     1  0.376643  1.090417  0.875619
# 16     1 -0.856523 -1.537767 -0.323998
# 17     1 -0.962223 -0.223675 -1.123743
# 18     1  0.765468  1.090417  1.276275
# 19     1  1.296484  1.090417  2.068039
# 20     1 -0.294048 -0.223675 -0.699878
# 21     1 -0.141790 -1.537767 -0.683083
# 22     1 -0.499157 -0.223675 -0.779852
# ...

# %%
data.shape
# Out:
# (47, 4)

# %%
cols = data.shape[1]
X = data.iloc[ : , : cols-1]
y = data.iloc[ : ,  cols-1:cols]

# %%
X
# Out:
#     Ones      Size     Rooms
# 0      1  0.130010 -0.223675
# 1      1 -0.504190 -0.223675
# 2      1  0.502476 -0.223675
# 3      1 -0.735723 -1.537767
# 4      1  1.257476  1.090417
# 5      1 -0.019732  1.090417
# 6      1 -0.587240 -0.223675
# 7      1 -0.721881 -0.223675
# 8      1 -0.781023 -0.223675
# 9      1 -0.637573 -0.223675
# 10     1 -0.076357  1.090417
# 11     1 -0.000857 -0.223675
# 12     1 -0.139273 -0.223675
# 13     1  3.117292  2.404508
# 14     1 -0.921956 -0.223675
# 15     1  0.376643  1.090417
# 16     1 -0.856523 -1.537767
# 17     1 -0.962223 -0.223675
# 18     1  0.765468  1.090417
# 19     1  1.296484  1.090417
# 20     1 -0.294048 -0.223675
# 21     1 -0.141790 -1.537767
# 22     1 -0.499157 -0.223675
# 23     1 -0.048673  1.090417
# 24     1  2.377392 -0.223675
# 25     1 -1.133356 -0.223675
# 26     1 -0.682873 -0.223675
# 27     1  0.661026 -0.223675
# 28     1  0.250810 -0.223675
# 29     1  0.800701 -0.223675
# 30     1 -0.203448 -1.537767
# ...

# %%
X.shape
# Out:
# (47, 3)

# %%
y
# Out:
#        Price
# 0   0.475747
# 1  -0.084074
# 2   0.228626
# 3  -0.867025
# 4   1.595389
# 5  -0.323998
# 6  -0.204036
# 7  -1.130948
# 8  -1.026973
# 9  -0.783051
# 10 -0.803053
# 11  0.052682
# 12 -0.083283
# 13  2.874981
# 14 -0.643896
# 15  0.875619
# 16 -0.323998
# 17 -1.123743
# 18  1.276275
# 19  2.068039
# 20 -0.699878
# 21 -0.683083
# 22 -0.779852
# 23 -0.643896
# 24  1.867303
# 25 -0.723870
# 26  0.992382
# 27  1.028370
# 28  1.076355
# 29 -0.323998
# 30  0.075875
# 31 -1.363666
# 32 -0.204036
# 33  1.915287
# 34 -0.435962
# 35 -0.723870
# 36 -0.883819
# 37  0.036687
# 38  1.668166
# 39 -0.427165
# 40  0.224627
# 41 -0.084074
# 42 -0.211234
# 43 -0.331196
# 44 -1.283692
# 45 -0.323998
# 46 -0.807044

# %%
y.shape
# Out:
# (47, 1)

# %%
X = np.matrix(X.values)
y = np.matrix(y.values)
theta = np.matrix(np.array([0,0,0]))

# %%
X.shape
# Out:
# (47, 3)

# %%
y.shape
# Out:
# (47, 1)

# %%
theta.shape
# Out:
# (1, 3)

# %%
X
# Out:
# matrix([[ 1.00000000e+00,  1.30009869e-01, -2.23675187e-01],
#         [ 1.00000000e+00, -5.04189838e-01, -2.23675187e-01],
#         [ 1.00000000e+00,  5.02476364e-01, -2.23675187e-01],
#         [ 1.00000000e+00, -7.35723065e-01, -1.53776691e+00],
#         [ 1.00000000e+00,  1.25747602e+00,  1.09041654e+00],
#         [ 1.00000000e+00, -1.97317285e-02,  1.09041654e+00],
#         [ 1.00000000e+00, -5.87239800e-01, -2.23675187e-01],
#         [ 1.00000000e+00, -7.21881404e-01, -2.23675187e-01],
#         [ 1.00000000e+00, -7.81023044e-01, -2.23675187e-01],
#         [ 1.00000000e+00, -6.37573110e-01, -2.23675187e-01],
#         [ 1.00000000e+00, -7.63567023e-02,  1.09041654e+00],
#         [ 1.00000000e+00, -8.56737193e-04, -2.23675187e-01],
#         [ 1.00000000e+00, -1.39273340e-01, -2.23675187e-01],
#         [ 1.00000000e+00,  3.11729182e+00,  2.40450826e+00],
#         [ 1.00000000e+00, -9.21956312e-01, -2.23675187e-01],
# ...

# %%
y
# Out:
# matrix([[ 0.47574687],
#         [-0.08407444],
#         [ 0.22862575],
#         [-0.86702453],
#         [ 1.59538948],
#         [-0.32399786],
#         [-0.20403615],
#         [-1.13094828],
#         [-1.02697347],
#         [-0.78305133],
#         [-0.80305294],
#         [ 0.05268191],
#         [-0.08328269],
#         [ 2.87498104],
#         [-0.64389575],
#         [ 0.87561923],
#         [-0.32399786],
#         [-1.12374258],
#         [ 1.27627534],
#         [ 2.06803861],
#         [-0.69987788],
#         [-0.68308324],
#         [-0.77985235],
#         [-0.64389575],
#         [ 1.86730269],
#         [-0.72387022],
#         [ 0.99238196],
#         [ 1.02837047],
#         [ 1.07635515],
#         [-0.32399786],
#         [ 0.0758745 ],
#         [-1.363666  ],
#         [-0.20403615],
#         [ 1.91528737],
#         [-0.43596212],
#         [-0.72387022],
#         [-0.88381916],
#         [ 0.03668701],
#         [ 1.66816625],
#         [-0.42716493],
# ...

# %%
theta
# Out:
# matrix([[0, 0, 0]])

# %%
def cos_func ( X , y ,theta ) :
    z = np.power(((X*theta.T) - y) , 2)
    return np.sum(z) / (2*len(X))

# %%
cos_func(X , y ,theta)
# Out:
# 0.48936170212765967

# %%
def gradiant_func (X , y , theta , Alpha , iters  ) :
    temp = np.matrix(np.zeros(theta.shape))
    parameter = int(theta.ravel().shape[1])
    cost = np.zeros(iters)
    for i in range(iters) :
        error = ( X * theta.T) - y
        for j in range(parameter) :
            term = np.multiply(error, X[:,j])
            temp[0,j] = theta[0,j] - ((Alpha / len(X)) * np.sum(term))
        theta = temp
        cost[i] = cos_func(X , y ,theta)
    return theta , cost

# %%
Alpha = 0.1
iters = 100

# %%
g  , cost = gradiant_func(X , y , theta , Alpha , iters)

# %%
g
# Out:
# matrix([[-1.10845139e-16,  8.79020847e-01, -4.74337322e-02]])

# %%
cost
# Out:
# array([0.40693147, 0.34617152, 0.30110291, 0.26742183, 0.24202804,
#        0.22268634, 0.20778332, 0.19615275, 0.18695011, 0.17956245,
#        0.17354364, 0.16856787, 0.1643961 , 0.16085209, 0.15780504,
#        0.15515715, 0.15283462, 0.1507812 , 0.14895353, 0.14731772,
#        0.14584693, 0.14451959, 0.14331811, 0.14222795, 0.14123687,
#        0.14033451, 0.13951191, 0.13876131, 0.13807589, 0.13744961,
#        0.13687711, 0.13635356, 0.13587464, 0.13543646, 0.13503547,
#        0.13466846, 0.13433251, 0.13402498, 0.13374344, 0.13348567,
#        0.13324967, 0.13303358, 0.13283572, 0.13265455, 0.13248866,
#        0.13233675, 0.13219766, 0.13207029, 0.13195365, 0.13184685,
#        0.13174905, 0.1316595 , 0.13157749, 0.1315024 , 0.13143363,
#        0.13137066, 0.131313  , 0.1312602 , 0.13121184, 0.13116757,
#        0.13112702, 0.13108989, 0.13105589, 0.13102476, 0.13099625,
#        0.13097014, 0.13094623, 0.13092434, 0.1309043 , 0.13088594,
# ...

# %%
x = np.linspace(data.Size.min() , data.Price.max() , 100)
x
# Out:
# array([-1.44542274, -1.40178229, -1.35814185, -1.31450141, -1.27086097,
#        -1.22722053, -1.18358008, -1.13993964, -1.0962992 , -1.05265876,
#        -1.00901832, -0.96537787, -0.92173743, -0.87809699, -0.83445655,
#        -0.7908161 , -0.74717566, -0.70353522, -0.65989478, -0.61625434,
#        -0.57261389, -0.52897345, -0.48533301, -0.44169257, -0.39805212,
#        -0.35441168, -0.31077124, -0.2671308 , -0.22349036, -0.17984991,
#        -0.13620947, -0.09256903, -0.04892859, -0.00528815,  0.0383523 ,
#         0.08199274,  0.12563318,  0.16927362,  0.21291407,  0.25655451,
#         0.30019495,  0.34383539,  0.38747583,  0.43111628,  0.47475672,
#         0.51839716,  0.5620376 ,  0.60567805,  0.64931849,  0.69295893,
#         0.73659937,  0.78023981,  0.82388026,  0.8675207 ,  0.91116114,
#         0.95480158,  0.99844203,  1.04208247,  1.08572291,  1.12936335,
#         1.17300379,  1.21664424,  1.26028468,  1.30392512,  1.34756556,
# ...

# %%
l = g[0 , 0] +(g[0,1]*x)
l
# Out:
# array([-1.27055672, -1.23219586, -1.193835  , -1.15547414, -1.11711329,
#        -1.07875243, -1.04039157, -1.00203071, -0.96366985, -0.92530899,
#        -0.88694813, -0.84858728, -0.81022642, -0.77186556, -0.7335047 ,
#        -0.69514384, -0.65678298, -0.61842213, -0.58006127, -0.54170041,
#        -0.50333955, -0.46497869, -0.42661783, -0.38825697, -0.34989612,
#        -0.31153526, -0.2731744 , -0.23481354, -0.19645268, -0.15809182,
#        -0.11973097, -0.08137011, -0.04300925, -0.00464839,  0.03371247,
#         0.07207333,  0.11043419,  0.14879504,  0.1871559 ,  0.22551676,
#         0.26387762,  0.30223848,  0.34059934,  0.37896019,  0.41732105,
#         0.45568191,  0.49404277,  0.53240363,  0.57076449,  0.60912535,
#         0.6474862 ,  0.68584706,  0.72420792,  0.76256878,  0.80092964,
#         0.8392905 ,  0.87765135,  0.91601221,  0.95437307,  0.99273393,
#         1.03109479,  1.06945565,  1.10781651,  1.14617736,  1.18453822,
# ...

# %%
fig , ax = plt.subplots(figsize = (5 , 5))
ax.plot(x , l , "r" , label = "prediction_line" )
ax.scatter(data.Size , data.Price , label = "data_distribution")
ax.legend(loc = 2)
ax.set_xlabel("Size")
ax.set_ylabel("Prise")
ax.set_title("Predct price based size")
# Out:
# Text(0.5, 1.0, 'Predct price based size')

# %%
x1 = np.linspace(data.Rooms.min() , data.Rooms.max() , 100)
l1 = g[0,0]+(g[0,1] *x)

# %%
fig , ax = plt.subplots(figsize = (5 , 5))
ax.plot(x1 , l1 , "r" , label = "prediction_line" )
ax.scatter(data.Rooms , data.Price , label = "data_distribution")
ax.legend(loc = 2)
ax.set_xlabel("Rooms")
ax.set_ylabel("Prise")
ax.set_title("Predct price based Rooms")
# Out:
# Text(0.5, 1.0, 'Predct price based Rooms')

# %%
fig , ax = plt.subplots(figsize = (5 , 5))
ax.plot( np.arange(iters) , cost , "r"  )

ax.set_xlabel("Iteration")
ax.set_ylabel("Cost")
ax.set_title("Cost_Func")
# Out:
# Text(0.5, 1.0, 'Cost_Func')
