# %% [markdown]
# # DataSist Liberary

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datasist as ds
# %matplotlib inline
import warnings as w
w.filterwarnings("ignore")

# %%
path = "G:\\Data Field\\D..S..Course\\Epslion Course\\Singularity DS\\Singularity-Data-Science\\Singularity-Data-Science\\09-Data Preprocessing and ETL\\code\\dastasets\\sendy_logistics.csv"
df = pd.read_csv(path)
df
# Out:
#              Order No       User Id Vehicle Type  Platform Type  \
# 0       Order_No_4211   User_Id_633         Bike              3
# 1      Order_No_25375  User_Id_2285         Bike              3
# 2       Order_No_1899   User_Id_265         Bike              3
# 3       Order_No_9336  User_Id_1402         Bike              3
# 4      Order_No_27883  User_Id_1737         Bike              1
# ...               ...           ...          ...            ...
# 21196   Order_No_8834  User_Id_2001         Bike              3
# 21197  Order_No_22892  User_Id_1796         Bike              3
# 21198   Order_No_2831  User_Id_2956         Bike              3
# 21199   Order_No_6174  User_Id_2524         Bike              1
# 21200   Order_No_9836   User_Id_718         Bike              3
#
#       Personal or Business  Placement - Day of Month  \
# 0                 Business                         9
# 1                 Personal                        12
# ...

# %% [markdown]
# * To present Structure_describe of data

# %%
ds.structdata.describe(df)
# Out:
# First five data points
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# ...

# %% [markdown]
# * To remove redendance data :
#     * Remove features that contains only one unique field as these features are redundant

# %%
ds.feature_engineering.drop_redundant(data = df)
# Out:
# Dropped ['Vehicle Type']
#              Order No       User Id  Platform Type Personal or Business  \
# 0       Order_No_4211   User_Id_633              3             Business
# 1      Order_No_25375  User_Id_2285              3             Personal
# 2       Order_No_1899   User_Id_265              3             Business
# 3       Order_No_9336  User_Id_1402              3             Business
# 4      Order_No_27883  User_Id_1737              1             Personal
# ...               ...           ...            ...                  ...
# 21196   Order_No_8834  User_Id_2001              3             Personal
# 21197  Order_No_22892  User_Id_1796              3             Business
# 21198   Order_No_2831  User_Id_2956              3             Business
# 21199   Order_No_6174  User_Id_2524              1             Personal
# 21200   Order_No_9836   User_Id_718              3             Business
#
#        Placement - Day of Month  Placement - Weekday (Mo = 1)  \
# ...

# %% [markdown]
# * Present Categorical_data

# %%
categorical_data = ds.structdata.get_cat_feats(data = df)
categorical_data
# Out:
# ['Order No',
#  'User Id',
#  'Vehicle Type',
#  'Personal or Business',
#  'Placement - Time',
#  'Confirmation - Time',
#  'Arrival at Pickup - Time',
#  'Pickup - Time',
#  'Arrival at Destination - Time',
#  'Rider Id']

# %% [markdown]
# * Present unique_counts

# %%
unique_data_count = ds.structdata.get_unique_counts(data = df)
unique_data_count
# Out:
# <style  type="text/css" >
#     #T_79b3ec9c_7c40_11eb_9b74_a02bb840f422row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_79b3ec9c_7c40_11eb_9b74_a02bb840f422row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 15.0%, transparent 15.0%);
#         }    #T_79b3ec9c_7c40_11eb_9b74_a02bb840f422row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }    #T_79b3ec9c_7c40_11eb_9b74_a02bb840f422row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }    #T_79b3ec9c_7c40_11eb_9b74_a02bb840f422row4_col1 {
#             width:  10em;
#              height:  80%;
# ...

# %% [markdown]
# * Present Visualization of categorical data

# %%
ds.visualizations.countplot(data = df)
# Out:
# Unique Values in Order No is too large to plot
#
#
# Unique Values in User Id is too large to plot
#
#
# Unique Values in Placement - Time is too large to plot
#
#
# Unique Values in Confirmation - Time is too large to plot
#
#
# Unique Values in Arrival at Pickup - Time is too large to plot
#
#
# Unique Values in Pickup - Time is too large to plot
#
#
# Unique Values in Arrival at Destination - Time is too large to plot
#
#
# Unique Values in Rider Id is too large to plot

# %%
ds.visualizations.class_count(data = df)
# Out:
# Unique classes in Order No too large
# Unique classes in User Id too large
# Class Count for Vehicle Type
#       Vehicle Type
# Bike         21201
# Class Count for Personal or Business
#           Personal or Business
# Business                 17384
# Personal                  3817
# Unique classes in Placement - Time too large
# Unique classes in Confirmation - Time too large
# Unique classes in Arrival at Pickup - Time too large
# Unique classes in Pickup - Time too large
# Unique classes in Arrival at Destination - Time too large
# Unique classes in Rider Id too large

# %%
df.columns
# Out:
# Index(['Order No', 'User Id', 'Vehicle Type', 'Platform Type',
#        'Personal or Business', 'Placement - Day of Month',
#        'Placement - Weekday (Mo = 1)', 'Placement - Time',
#        'Confirmation - Day of Month', 'Confirmation - Weekday (Mo = 1)',
#        'Confirmation - Time', 'Arrival at Pickup - Day of Month',
#        'Arrival at Pickup - Weekday (Mo = 1)', 'Arrival at Pickup - Time',
#        'Pickup - Day of Month', 'Pickup - Weekday (Mo = 1)', 'Pickup - Time',
#        'Arrival at Destination - Day of Month',
#        'Arrival at Destination - Weekday (Mo = 1)',
#        'Arrival at Destination - Time', 'Distance (KM)', 'Temperature',
#        'Precipitation in millimeters', 'Pickup Lat', 'Pickup Long',
#        'Destination Lat', 'Destination Long', 'Rider Id',
#        'Time from Pickup to Arrival'],
#       dtype='object')

# %%
ds.visualizations.catbox(data = df , target="Personal or Business" , fig_size=(10,10))
# Out:
# Order No feature has too many categories and will not be ploted
# User Id feature has too many categories and will not be ploted
# Placement - Time feature has too many categories and will not be ploted
# Confirmation - Time feature has too many categories and will not be ploted
# Arrival at Pickup - Time feature has too many categories and will not be ploted
# Pickup - Time feature has too many categories and will not be ploted
# Arrival at Destination - Time feature has too many categories and will not be ploted
# Rider Id feature has too many categories and will not be ploted

# %%
ds.visualizations.boxplot(data = df , target="Personal or Business" , fig_size=(10,10))

# %% [markdown]
# * Visualize Numerical features

# %%
ds.visualizations.histogram(data = df , fig_size=(10,10) , bins=5)

# %% [markdown]
# * Time_Features

# %%
data_feats = ds.structdata.get_date_cols(df)
data_feats
# Out:
# set()

# %%
num_feats = ds.structdata.get_num_feats(df)
num_feats
# Out:
# ['Platform Type',
#  'Placement - Day of Month',
#  'Placement - Weekday (Mo = 1)',
#  'Confirmation - Day of Month',
#  'Confirmation - Weekday (Mo = 1)',
#  'Arrival at Pickup - Day of Month',
#  'Arrival at Pickup - Weekday (Mo = 1)',
#  'Pickup - Day of Month',
#  'Pickup - Weekday (Mo = 1)',
#  'Arrival at Destination - Day of Month',
#  'Arrival at Destination - Weekday (Mo = 1)',
#  'Distance (KM)',
#  'Temperature',
#  'Precipitation in millimeters',
#  'Pickup Lat',
#  'Pickup Long',
#  'Destination Lat',
#  'Destination Long',
#  'Time from Pickup to Arrival']

# %%
ds.timeseries.timeplot(data=df,num_cols=num_feats, time_col='Time from Pickup to Arrival')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-a07a74a561ce> in <module>
# ----> 1 ds.timeseries.timeplot(data=df,num_cols=num_feats, time_col='Time from Pickup to Arrival')
#
# C:\ProgramData\Anaconda3\lib\site-packages\datasist\timeseries.py in timeplot(data, num_cols, time_col, subplots, marker, figsize, y_label, save_fig, alpha, linestyle)
#     327
#     328     if subplots:
# --> 329         axes = data[num_cols].plot(marker=marker,subplots=True, figsize=figsize, alpha=0.5, linestyle=linestyle)
#     330         for feature, ax in zip(num_cols, axes):
#     331             ax.set_ylabel(y_label)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# ...
